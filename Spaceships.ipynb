# %%
import pandas as pd

# %%
# Used Pandas to retrieve data from table in html rather than BeautifulSoup
# First table of Orbital crewed spaceship
df1 = (pd.read_html('https://en.wikipedia.org/wiki/Comparison_of_crewed_space_vehicles'))[0]
df1.head()
# Out:
#                       0       1                                           2   \
# 0             Spacecraft  Origin                                Manufacturer
# 1                Mercury     USA   McDonnell AircraftNorth American Aviation
# 2                 Gemini     USA                    McDonnell AircraftMartin
# 3                 Apollo     USA  North American AviationGrumman and Douglas
# 4  Space Shuttle orbiter     USA                       United Space Alliance
#
#             3                               4          5           6   \
# 0        Range                    Launchsystem   Crewsize  Length (m)
# 1  LEOattained        Redstone MRLVAtlas LV-3B          1        3.34
# 2          LEO  Titan II GLVTitan IIIC[note 2]          2        5.56
# 3        Lunar               Saturn IBSaturn V          3         8.5
# 4          LEO                   Space Shuttle  8[note 4]       37.24
#
#              7                                          8            9   \
# 0  Diameter (m)                           Launch mass (kg)  Powersystem
# 1          1.89                                        NaN    Batteries
# 2          3.05                                        NaN   Fuel cells
# 3          3.91  5,500 CM + 14,700 LM24,500 Service Module   Fuel cells
# 4   4.8[note 5]                                     109000   Fuel cells
#
#                         10                 11               12             13
# 0  Payloadto/from ISS (kg)  Firstspaceflight*  Lastspaceflight       Flights*
# 1                      NaN        1961 (1960)             1963  6(12)[note 1]
# 2                      NaN        1965 (1964)             1966  10(2)[note 3]
# 3                      NaN        1967 (1966)             1975  15(4)[note 3]
# 4            12,500/16,000               1981             2011    135[note 6]

# %%
# Gets first row as a list to use as new header
header_1 = df1.iloc[0]
header_1
# Out:
# 0                  Spacecraft
# 1                      Origin
# 2                Manufacturer
# 3                       Range
# 4                Launchsystem
# 5                    Crewsize
# 6                  Length (m)
# 7                Diameter (m)
# 8            Launch mass (kg)
# 9                 Powersystem
# 10    Payloadto/from ISS (kg)
# 11          Firstspaceflight*
# 12            Lastspaceflight
# 13                   Flights*
# Name: 0, dtype: object

# %%
# Reset df to drop first row with header names
df1 = df1[1:]
df1.head()
# Out:
#                       0    1                                           2   \
# 1                Mercury  USA   McDonnell AircraftNorth American Aviation
# 2                 Gemini  USA                    McDonnell AircraftMartin
# 3                 Apollo  USA  North American AviationGrumman and Douglas
# 4  Space Shuttle orbiter  USA                       United Space Alliance
# 5                  Orion  USA                      Lockheed MartinAstrium
#
#             3                                  4          5      6   \
# 1  LEOattained           Redstone MRLVAtlas LV-3B          1   3.34
# 2          LEO     Titan II GLVTitan IIIC[note 2]          2   5.56
# 3        Lunar                  Saturn IBSaturn V          3    8.5
# 4          LEO                      Space Shuttle  8[note 4]  37.24
# 5         Mars  Delta IV HeavySpace Launch System          6    3.3
#
#             7                                          8             9   \
# 1         1.89                                        NaN     Batteries
# 2         3.05                                        NaN    Fuel cells
# 3         3.91  5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 4  4.8[note 5]                                     109000    Fuel cells
# 5            5         8,900 Capsule12,300 Service Module  Solar Panels
#
#               10                    11    12             13
# 1            NaN           1961 (1960)  1963  6(12)[note 1]
# 2            NaN           1965 (1964)  1966  10(2)[note 3]
# 3            NaN           1967 (1966)  1975  15(4)[note 3]
# 4  12,500/16,000                  1981  2011    135[note 6]
# 5            NaN  Planned: 2021 (2014)   NaN  0 (1)[note 7]

# %%
df1.rename(columns=header_1, inplace=True)
df1.head()
# Out:
#               Spacecraft Origin                                Manufacturer  \
# 1                Mercury    USA   McDonnell AircraftNorth American Aviation
# 2                 Gemini    USA                    McDonnell AircraftMartin
# 3                 Apollo    USA  North American AviationGrumman and Douglas
# 4  Space Shuttle orbiter    USA                       United Space Alliance
# 5                  Orion    USA                      Lockheed MartinAstrium
#
#          Range                       Launchsystem   Crewsize Length (m)  \
# 1  LEOattained           Redstone MRLVAtlas LV-3B          1       3.34
# 2          LEO     Titan II GLVTitan IIIC[note 2]          2       5.56
# 3        Lunar                  Saturn IBSaturn V          3        8.5
# 4          LEO                      Space Shuttle  8[note 4]      37.24
# 5         Mars  Delta IV HeavySpace Launch System          6        3.3
#
#   Diameter (m)                           Launch mass (kg)   Powersystem  \
# 1         1.89                                        NaN     Batteries
# 2         3.05                                        NaN    Fuel cells
# 3         3.91  5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 4  4.8[note 5]                                     109000    Fuel cells
# 5            5         8,900 Capsule12,300 Service Module  Solar Panels
#
#   Payloadto/from ISS (kg)     Firstspaceflight* Lastspaceflight       Flights*
# 1                     NaN           1961 (1960)            1963  6(12)[note 1]
# 2                     NaN           1965 (1964)            1966  10(2)[note 3]
# 3                     NaN           1967 (1966)            1975  15(4)[note 3]
# 4           12,500/16,000                  1981            2011    135[note 6]
# 5                     NaN  Planned: 2021 (2014)             NaN  0 (1)[note 7]

# %%
# Add orbital type that separates table subjects
df1['Orbit'] = "Orbital"

# %%
# Second table of Sub-orbital crewed spaceship
df2 = (pd.read_html('https://en.wikipedia.org/wiki/Comparison_of_crewed_space_vehicles'))[0]
df2.head()
# Out:
#                       0       1                                           2   \
# 0             Spacecraft  Origin                                Manufacturer
# 1                Mercury     USA   McDonnell AircraftNorth American Aviation
# 2                 Gemini     USA                    McDonnell AircraftMartin
# 3                 Apollo     USA  North American AviationGrumman and Douglas
# 4  Space Shuttle orbiter     USA                       United Space Alliance
#
#             3                               4          5           6   \
# 0        Range                    Launchsystem   Crewsize  Length (m)
# 1  LEOattained        Redstone MRLVAtlas LV-3B          1        3.34
# 2          LEO  Titan II GLVTitan IIIC[note 2]          2        5.56
# 3        Lunar               Saturn IBSaturn V          3         8.5
# 4          LEO                   Space Shuttle  8[note 4]       37.24
#
#              7                                          8            9   \
# 0  Diameter (m)                           Launch mass (kg)  Powersystem
# 1          1.89                                        NaN    Batteries
# 2          3.05                                        NaN   Fuel cells
# 3          3.91  5,500 CM + 14,700 LM24,500 Service Module   Fuel cells
# 4   4.8[note 5]                                     109000   Fuel cells
#
#                         10                 11               12             13
# 0  Payloadto/from ISS (kg)  Firstspaceflight*  Lastspaceflight       Flights*
# 1                      NaN        1961 (1960)             1963  6(12)[note 1]
# 2                      NaN        1965 (1964)             1966  10(2)[note 3]
# 3                      NaN        1967 (1966)             1975  15(4)[note 3]
# 4            12,500/16,000               1981             2011    135[note 6]

# %%
df2 = df2.rename(columns=df2.iloc[0]).drop(df2.index[0])
df2.head()
# Out:
#               Spacecraft Origin                                Manufacturer  \
# 1                Mercury    USA   McDonnell AircraftNorth American Aviation
# 2                 Gemini    USA                    McDonnell AircraftMartin
# 3                 Apollo    USA  North American AviationGrumman and Douglas
# 4  Space Shuttle orbiter    USA                       United Space Alliance
# 5                  Orion    USA                      Lockheed MartinAstrium
#
#          Range                       Launchsystem   Crewsize Length (m)  \
# 1  LEOattained           Redstone MRLVAtlas LV-3B          1       3.34
# 2          LEO     Titan II GLVTitan IIIC[note 2]          2       5.56
# 3        Lunar                  Saturn IBSaturn V          3        8.5
# 4          LEO                      Space Shuttle  8[note 4]      37.24
# 5         Mars  Delta IV HeavySpace Launch System          6        3.3
#
#   Diameter (m)                           Launch mass (kg)   Powersystem  \
# 1         1.89                                        NaN     Batteries
# 2         3.05                                        NaN    Fuel cells
# 3         3.91  5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 4  4.8[note 5]                                     109000    Fuel cells
# 5            5         8,900 Capsule12,300 Service Module  Solar Panels
#
#   Payloadto/from ISS (kg)     Firstspaceflight* Lastspaceflight       Flights*
# 1                     NaN           1961 (1960)            1963  6(12)[note 1]
# 2                     NaN           1965 (1964)            1966  10(2)[note 3]
# 3                     NaN           1967 (1966)            1975  15(4)[note 3]
# 4           12,500/16,000                  1981            2011    135[note 6]
# 5                     NaN  Planned: 2021 (2014)             NaN  0 (1)[note 7]

# %%
df2['Orbit'] = "Sub-Orbital"

# %%
# See which columns can be joined on
list(df1.columns)
# Out:
# ['Spacecraft',
#  'Origin',
#  'Manufacturer',
#  'Range',
#  'Launchsystem',
#  'Crewsize',
#  'Length (m)',
#  'Diameter (m)',
#  'Launch mass (kg)',
#  'Powersystem',
#  'Payloadto/from ISS (kg)',
#  'Firstspaceflight*',
#  'Lastspaceflight',
#  'Flights*',
#  'Orbit']

# %%
# See which columns can be joined on
list(df2.columns)
# Out:
# ['Spacecraft',
#  'Origin',
#  'Manufacturer',
#  'Range',
#  'Launchsystem',
#  'Crewsize',
#  'Length (m)',
#  'Diameter (m)',
#  'Launch mass (kg)',
#  'Powersystem',
#  'Payloadto/from ISS (kg)',
#  'Firstspaceflight*',
#  'Lastspaceflight',
#  'Flights*',
#  'Orbit']

# %%
df3 = df1.merge(df2,how='outer')
df3
# Out:
#                Spacecraft               Origin  \
# 0                 Mercury                  USA
# 1                  Gemini                  USA
# 2                  Apollo                  USA
# 3   Space Shuttle orbiter                  USA
# 4                   Orion                  USA
# 5                Shenzhou                China
# 6               Gaganyaan                India
# 7              Soyuz 7K-T         Soviet Union
# 8                 Voskhod         Soviet Union
# 9                  Vostok         Soviet Union
# 10            Soyuz 7K-OK         Soviet Union
# 11           Soyuz 7KT-OK         Soviet Union
# 12          Soyuz 7K-T-AF         Soviet Union
# 13            Soyuz 7K-TM         Soviet Union
# 14           Soyuz 7K-MF6         Soviet Union
# 15                Soyuz-T         Soviet Union
# 16               Soyuz-TM  Soviet Union Russia
# 17                  Buran         Soviet Union
# 18        Soyuz-TMA11F732               Russia
# 19      Soyuz TMA-M11F747               Russia
# 20               Soyuz MS               Russia
# 21            Federatsiya               Russia
# 22  Biconic Space Vehicle                  USA
# 23      CST-100 Starliner                  USA
# 24           Dream Chaser                  USA
# 25               Dragon 2                  USA
# 26               Starship                  USA
# 27                Mercury                  USA
# 28                 Gemini                  USA
# 29                 Apollo                  USA
# 30  Space Shuttle orbiter                  USA
# 31                  Orion                  USA
# 32               Shenzhou                China
# 33              Gaganyaan                India
# 34             Soyuz 7K-T         Soviet Union
# 35                Voskhod         Soviet Union
# 36                 Vostok         Soviet Union
# 37            Soyuz 7K-OK         Soviet Union
# 38           Soyuz 7KT-OK         Soviet Union
# 39          Soyuz 7K-T-AF         Soviet Union
# 40            Soyuz 7K-TM         Soviet Union
# 41           Soyuz 7K-MF6         Soviet Union
# 42                Soyuz-T         Soviet Union
# 43               Soyuz-TM  Soviet Union Russia
# 44                  Buran         Soviet Union
# 45        Soyuz-TMA11F732               Russia
# 46      Soyuz TMA-M11F747               Russia
# 47               Soyuz MS               Russia
# 48            Federatsiya               Russia
# 49  Biconic Space Vehicle                  USA
# 50      CST-100 Starliner                  USA
# 51           Dream Chaser                  USA
# 52               Dragon 2                  USA
# 53               Starship                  USA
#
#                                   Manufacturer                      Range  \
# 0    McDonnell AircraftNorth American Aviation                LEOattained
# 1                     McDonnell AircraftMartin                        LEO
# 2   North American AviationGrumman and Douglas                      Lunar
# 3                        United Space Alliance                        LEO
# 4                       Lockheed MartinAstrium                       Mars
# 5            China Academy of Space Technology                        LEO
# 6                Hindustan Aeronautics Limited                        LEO
# 7                                        OKB-1                        LEO
# 8                                        OKB-1                        LEO
# 9                                        OKB-1                   LEOfirst
# 10                                       OKB-1                        LEO
# 11                                       OKB-1                        LEO
# 12                                       OKB-1                        LEO
# 13                                       OKB-1                        LEO
# 14                                       OKB-1                        LEO
# 15                                       OKB-1                        LEO
# 16                                 RKK Energia                        LEO
# 17                                 RKK Energia                        LEO
# 18                                 RKK Energia                        LEO
# 19                                 RKK Energia                        LEO
# 20                                 RKK Energia                        LEO
# 21                                 RKK Energia                      Lunar
# 22                                 Blue Origin                        LEO
# 23                                      Boeing                        LEO
# 24                   Sierra Nevada Corporation                        LEO
# 25                                      SpaceX                        LEO
# 26                                      SpaceX  Solar System[10][note 15]
# 27   McDonnell AircraftNorth American Aviation                LEOattained
# 28                    McDonnell AircraftMartin                        LEO
# 29  North American AviationGrumman and Douglas                      Lunar
# 30                       United Space Alliance                        LEO
# 31                      Lockheed MartinAstrium                       Mars
# 32           China Academy of Space Technology                        LEO
# 33               Hindustan Aeronautics Limited                        LEO
# 34                                       OKB-1                        LEO
# 35                                       OKB-1                        LEO
# 36                                       OKB-1                   LEOfirst
# 37                                       OKB-1                        LEO
# 38                                       OKB-1                        LEO
# 39                                       OKB-1                        LEO
# 40                                       OKB-1                        LEO
# 41                                       OKB-1                        LEO
# 42                                       OKB-1                        LEO
# 43                                 RKK Energia                        LEO
# 44                                 RKK Energia                        LEO
# 45                                 RKK Energia                        LEO
# 46                                 RKK Energia                        LEO
# 47                                 RKK Energia                        LEO
# 48                                 RKK Energia                      Lunar
# 49                                 Blue Origin                        LEO
# 50                                      Boeing                        LEO
# 51                   Sierra Nevada Corporation                        LEO
# 52                                      SpaceX                        LEO
# 53                                      SpaceX  Solar System[10][note 15]
#
#                          Launchsystem      Crewsize Length (m)  \
# 0            Redstone MRLVAtlas LV-3B             1       3.34
# 1      Titan II GLVTitan IIIC[note 2]             2       5.56
# 2                   Saturn IBSaturn V             3        8.5
# 3                       Space Shuttle     8[note 4]      37.24
# 4   Delta IV HeavySpace Launch System             6        3.3
# 5                      Chang Zheng 2F             3       9.25
# 6                         GSLV Mk III             3          7
# 7                        SoyuzSoyuz-U             2       7.48
# 8                             Voskhod     3[note 9]          5
# 9                            Vostok-K             1        4.4
# 10                              Soyuz             3       7.48
# 11                              Soyuz             3       7.48
# 12                              Soyuz             2       7.48
# 13                            Soyuz-U             2       7.48
# 14                            Soyuz-U             2       7.48
# 15                    Soyuz-USoyuz-U2             3       7.48
# 16                    Soyuz-U2Soyuz-U             3       7.48
# 17                            Energia            10      36.37
# 18                           Soyuz-FG             3       7.48
# 19                           Soyuz-FG             3       7.48
# 20                           Soyuz-FG             3       7.48
# 21                    Soyuz-5Angara 5             4        NaN
# 22                          New Glenn           NaN        NaN
# 23        multiple, initially Atlas V         7 [1]   5.03 [2]
# 24        multiple, initially Atlas V      7 [3][4]      9 [5]
# 25                           Falcon 9    7[note 14]     8.1[7]
# 26                            BFR[10]  100[note 16]     55[10]
# 27           Redstone MRLVAtlas LV-3B             1       3.34
# 28     Titan II GLVTitan IIIC[note 2]             2       5.56
# 29                  Saturn IBSaturn V             3        8.5
# 30                      Space Shuttle     8[note 4]      37.24
# 31  Delta IV HeavySpace Launch System             6        3.3
# 32                     Chang Zheng 2F             3       9.25
# 33                        GSLV Mk III             3          7
# 34                       SoyuzSoyuz-U             2       7.48
# 35                            Voskhod     3[note 9]          5
# 36                           Vostok-K             1        4.4
# 37                              Soyuz             3       7.48
# 38                              Soyuz             3       7.48
# 39                              Soyuz             2       7.48
# 40                            Soyuz-U             2       7.48
# 41                            Soyuz-U             2       7.48
# 42                    Soyuz-USoyuz-U2             3       7.48
# 43                    Soyuz-U2Soyuz-U             3       7.48
# 44                            Energia            10      36.37
# 45                           Soyuz-FG             3       7.48
# 46                           Soyuz-FG             3       7.48
# 47                           Soyuz-FG             3       7.48
# 48                    Soyuz-5Angara 5             4        NaN
# 49                          New Glenn           NaN        NaN
# 50        multiple, initially Atlas V         7 [1]   5.03 [2]
# 51        multiple, initially Atlas V      7 [3][4]      9 [5]
# 52                           Falcon 9    7[note 14]     8.1[7]
# 53                            BFR[10]  100[note 16]     55[10]
#
#       Diameter (m)                           Launch mass (kg)   Powersystem  \
# 0             1.89                                        NaN     Batteries
# 1             3.05                                        NaN    Fuel cells
# 2             3.91  5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 3      4.8[note 5]                                     109000    Fuel cells
# 4                5         8,900 Capsule12,300 Service Module  Solar Panels
# 5             2.80                                       7840  Solar panels
# 6                3                                       7800  Solar Panels
# 7             2.72                                        NaN     Batteries
# 8              2.4                                        NaN     Batteries
# 9             2.43                                       4725     Batteries
# 10            2.72                                        NaN  Solar panels
# 11            2.72                                        NaN  Solar panels
# 12            2.72                                        NaN  Solar panels
# 13            2.72                                        NaN  Solar panels
# 14            2.72                                        NaN  Solar panels
# 15            2.72                                        NaN  Solar panels
# 16            2.72                                        NaN  Solar panels
# 17             NaN                                        NaN    Fuel cells
# 18            2.72                                        NaN  Solar panels
# 19            2.72                                       7150  Solar panels
# 20            2.72                                        NaN  Solar panels
# 21             NaN                                        NaN  Solar panels
# 22             NaN                                        NaN           NaN
# 23        4.56 [2]                                        NaN  Solar panels
# 24             NaN                                 11,300 [6]           NaN
# 25          3.7[8]                    12,055 kg(26,577 lb)[9]  Solar Panels
# 26  9[10][note 17]                              1,335,000[10]  Solar Panels
# 27            1.89                                        NaN     Batteries
# 28            3.05                                        NaN    Fuel cells
# 29            3.91  5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 30     4.8[note 5]                                     109000    Fuel cells
# 31               5         8,900 Capsule12,300 Service Module  Solar Panels
# 32            2.80                                       7840  Solar panels
# 33               3                                       7800  Solar Panels
# 34            2.72                                        NaN     Batteries
# 35             2.4                                        NaN     Batteries
# 36            2.43                                       4725     Batteries
# 37            2.72                                        NaN  Solar panels
# 38            2.72                                        NaN  Solar panels
# 39            2.72                                        NaN  Solar panels
# 40            2.72                                        NaN  Solar panels
# 41            2.72                                        NaN  Solar panels
# 42            2.72                                        NaN  Solar panels
# 43            2.72                                        NaN  Solar panels
# 44             NaN                                        NaN    Fuel cells
# 45            2.72                                        NaN  Solar panels
# 46            2.72                                       7150  Solar panels
# 47            2.72                                        NaN  Solar panels
# 48             NaN                                        NaN  Solar panels
# 49             NaN                                        NaN           NaN
# 50        4.56 [2]                                        NaN  Solar panels
# 51             NaN                                 11,300 [6]           NaN
# 52          3.7[8]                    12,055 kg(26,577 lb)[9]  Solar Panels
# 53  9[10][note 17]                              1,335,000[10]  Solar Panels
#
#    Payloadto/from ISS (kg)                Firstspaceflight* Lastspaceflight  \
# 0                      NaN                      1961 (1960)            1963
# 1                      NaN                      1965 (1964)            1966
# 2                      NaN                      1967 (1966)            1975
# 3            12,500/16,000                             1981            2011
# 4                      NaN             Planned: 2021 (2014)             NaN
# 5                      NaN                      2003 (1999)          Active
# 6                      NaN                             2021             NaN
# 7                      NaN                             1973            1981
# 8                      NaN                      1964 (1964)            1965
# 9                      NaN                      1961 (1960)            1963
# 10                     NaN                      1967 (1966)            1970
# 11                     NaN                             1971            1971
# 12                     NaN                             1973            1973
# 13                     NaN                             1974            1975
# 14                     NaN                             1976            1976
# 15                     NaN                             1978            1986
# 16                     NaN                             1986            2002
# 17                     NaN                           (1988)          (1988)
# 18                     NaN                             2002            2012
# 19                     NaN                             2010            2016
# 20                     NaN                             2016          Active
# 21                     NaN                    Planned: 2023             NaN
# 22                     NaN           Planned date not known             NaN
# 23                     NaN                    Planned: 2019             NaN
# 24                     NaN           Planned date not known             NaN
# 25             3,307/2,507             Planned: 2019 (2019)          Active
# 26                     NaN  planned (2020) [10]planned 2023             NaN
# 27                     NaN                      1961 (1960)            1963
# 28                     NaN                      1965 (1964)            1966
# 29                     NaN                      1967 (1966)            1975
# 30           12,500/16,000                             1981            2011
# 31                     NaN             Planned: 2021 (2014)             NaN
# 32                     NaN                      2003 (1999)          Active
# 33                     NaN                             2021             NaN
# 34                     NaN                             1973            1981
# 35                     NaN                      1964 (1964)            1965
# 36                     NaN                      1961 (1960)            1963
# 37                     NaN                      1967 (1966)            1970
# 38                     NaN                             1971            1971
# 39                     NaN                             1973            1973
# 40                     NaN                             1974            1975
# 41                     NaN                             1976            1976
# 42                     NaN                             1978            1986
# 43                     NaN                             1986            2002
# 44                     NaN                           (1988)          (1988)
# 45                     NaN                             2002            2012
# 46                     NaN                             2010            2016
# 47                     NaN                             2016          Active
# 48                     NaN                    Planned: 2023             NaN
# 49                     NaN           Planned date not known             NaN
# 50                     NaN                    Planned: 2019             NaN
# 51                     NaN           Planned date not known             NaN
# 52             3,307/2,507             Planned: 2019 (2019)          Active
# 53                     NaN  planned (2020) [10]planned 2023             NaN
#
#            Flights*        Orbit
# 0     6(12)[note 1]      Orbital
# 1     10(2)[note 3]      Orbital
# 2     15(4)[note 3]      Orbital
# 3       135[note 6]      Orbital
# 4     0 (1)[note 7]      Orbital
# 5              7(4)      Orbital
# 6                 0      Orbital
# 7    26 (4)[note 8]      Orbital
# 8             2 (3)      Orbital
# 9    6 (7)[note 10]      Orbital
# 10   8 (8)[note 11]      Orbital
# 11       2[note 12]      Orbital
# 12                1      Orbital
# 13            2 (2)      Orbital
# 14                1      Orbital
# 15  15 (6)[note 13]      Orbital
# 16           33 (1)      Orbital
# 17              (1)      Orbital
# 18               22      Orbital
# 19               19      Orbital
# 20                3      Orbital
# 21                0      Orbital
# 22                0      Orbital
# 23                0      Orbital
# 24                0      Orbital
# 25             0(1)      Orbital
# 26                0      Orbital
# 27    6(12)[note 1]  Sub-Orbital
# 28    10(2)[note 3]  Sub-Orbital
# 29    15(4)[note 3]  Sub-Orbital
# 30      135[note 6]  Sub-Orbital
# 31    0 (1)[note 7]  Sub-Orbital
# 32             7(4)  Sub-Orbital
# 33                0  Sub-Orbital
# 34   26 (4)[note 8]  Sub-Orbital
# 35            2 (3)  Sub-Orbital
# 36   6 (7)[note 10]  Sub-Orbital
# 37   8 (8)[note 11]  Sub-Orbital
# 38       2[note 12]  Sub-Orbital
# 39                1  Sub-Orbital
# 40            2 (2)  Sub-Orbital
# 41                1  Sub-Orbital
# 42  15 (6)[note 13]  Sub-Orbital
# 43           33 (1)  Sub-Orbital
# 44              (1)  Sub-Orbital
# 45               22  Sub-Orbital
# 46               19  Sub-Orbital
# 47                3  Sub-Orbital
# 48                0  Sub-Orbital
# 49                0  Sub-Orbital
# 50                0  Sub-Orbital
# 51                0  Sub-Orbital
# 52             0(1)  Sub-Orbital
# 53                0  Sub-Orbital

# %%
# Extract only US ships
# for each in ship_df:
#     if each.Origin = 'USA':
#         each

ship_df = df3[df3.Origin == 'USA']
ship_df.head()
# Out:
#               Spacecraft Origin                                Manufacturer  \
# 0                Mercury    USA   McDonnell AircraftNorth American Aviation
# 1                 Gemini    USA                    McDonnell AircraftMartin
# 2                 Apollo    USA  North American AviationGrumman and Douglas
# 3  Space Shuttle orbiter    USA                       United Space Alliance
# 4                  Orion    USA                      Lockheed MartinAstrium
#
#          Range                       Launchsystem   Crewsize Length (m)  \
# 0  LEOattained           Redstone MRLVAtlas LV-3B          1       3.34
# 1          LEO     Titan II GLVTitan IIIC[note 2]          2       5.56
# 2        Lunar                  Saturn IBSaturn V          3        8.5
# 3          LEO                      Space Shuttle  8[note 4]      37.24
# 4         Mars  Delta IV HeavySpace Launch System          6        3.3
#
#   Diameter (m)                           Launch mass (kg)   Powersystem  \
# 0         1.89                                        NaN     Batteries
# 1         3.05                                        NaN    Fuel cells
# 2         3.91  5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 3  4.8[note 5]                                     109000    Fuel cells
# 4            5         8,900 Capsule12,300 Service Module  Solar Panels
#
#   Payloadto/from ISS (kg)     Firstspaceflight* Lastspaceflight  \
# 0                     NaN           1961 (1960)            1963
# 1                     NaN           1965 (1964)            1966
# 2                     NaN           1967 (1966)            1975
# 3           12,500/16,000                  1981            2011
# 4                     NaN  Planned: 2021 (2014)             NaN
#
#         Flights*    Orbit
# 0  6(12)[note 1]  Orbital
# 1  10(2)[note 3]  Orbital
# 2  15(4)[note 3]  Orbital
# 3    135[note 6]  Orbital
# 4  0 (1)[note 7]  Orbital

# %%
# Rename Launchsytem, Crewsize, Powersystem, Payloadto/from ISS (kg), Firstspaceflight*, Lastspaceflight, Flights* fields
ship_df = ship_df.rename(columns={"Launchsystem":"Launch System", "Crewsize":"Crew Size", "Powersystem":"Power System", "Payloadto/from ISS (kg)":"Payload to/from ISS (kg)", "Firstspaceflight*":"First Space Flight","Lastspaceflight":"Last Space Flight", "Flights*":"Flights"})
ship_df
# Out:
#                Spacecraft Origin                                Manufacturer  \
# 0                 Mercury    USA   McDonnell AircraftNorth American Aviation
# 1                  Gemini    USA                    McDonnell AircraftMartin
# 2                  Apollo    USA  North American AviationGrumman and Douglas
# 3   Space Shuttle orbiter    USA                       United Space Alliance
# 4                   Orion    USA                      Lockheed MartinAstrium
# 22  Biconic Space Vehicle    USA                                 Blue Origin
# 23      CST-100 Starliner    USA                                      Boeing
# 24           Dream Chaser    USA                   Sierra Nevada Corporation
# 25               Dragon 2    USA                                      SpaceX
# 26               Starship    USA                                      SpaceX
# 27                Mercury    USA   McDonnell AircraftNorth American Aviation
# 28                 Gemini    USA                    McDonnell AircraftMartin
# 29                 Apollo    USA  North American AviationGrumman and Douglas
# 30  Space Shuttle orbiter    USA                       United Space Alliance
# 31                  Orion    USA                      Lockheed MartinAstrium
# 49  Biconic Space Vehicle    USA                                 Blue Origin
# 50      CST-100 Starliner    USA                                      Boeing
# 51           Dream Chaser    USA                   Sierra Nevada Corporation
# 52               Dragon 2    USA                                      SpaceX
# 53               Starship    USA                                      SpaceX
#
#                         Range                      Launch System  \
# 0                 LEOattained           Redstone MRLVAtlas LV-3B
# 1                         LEO     Titan II GLVTitan IIIC[note 2]
# 2                       Lunar                  Saturn IBSaturn V
# 3                         LEO                      Space Shuttle
# 4                        Mars  Delta IV HeavySpace Launch System
# 22                        LEO                          New Glenn
# 23                        LEO        multiple, initially Atlas V
# 24                        LEO        multiple, initially Atlas V
# 25                        LEO                           Falcon 9
# 26  Solar System[10][note 15]                            BFR[10]
# 27                LEOattained           Redstone MRLVAtlas LV-3B
# 28                        LEO     Titan II GLVTitan IIIC[note 2]
# 29                      Lunar                  Saturn IBSaturn V
# 30                        LEO                      Space Shuttle
# 31                       Mars  Delta IV HeavySpace Launch System
# 49                        LEO                          New Glenn
# 50                        LEO        multiple, initially Atlas V
# 51                        LEO        multiple, initially Atlas V
# 52                        LEO                           Falcon 9
# 53  Solar System[10][note 15]                            BFR[10]
#
#        Crew Size Length (m)    Diameter (m)  \
# 0              1       3.34            1.89
# 1              2       5.56            3.05
# 2              3        8.5            3.91
# 3      8[note 4]      37.24     4.8[note 5]
# 4              6        3.3               5
# 22           NaN        NaN             NaN
# 23         7 [1]   5.03 [2]        4.56 [2]
# 24      7 [3][4]      9 [5]             NaN
# 25    7[note 14]     8.1[7]          3.7[8]
# 26  100[note 16]     55[10]  9[10][note 17]
# 27             1       3.34            1.89
# 28             2       5.56            3.05
# 29             3        8.5            3.91
# 30     8[note 4]      37.24     4.8[note 5]
# 31             6        3.3               5
# 49           NaN        NaN             NaN
# 50         7 [1]   5.03 [2]        4.56 [2]
# 51      7 [3][4]      9 [5]             NaN
# 52    7[note 14]     8.1[7]          3.7[8]
# 53  100[note 16]     55[10]  9[10][note 17]
#
#                              Launch mass (kg)  Power System  \
# 0                                         NaN     Batteries
# 1                                         NaN    Fuel cells
# 2   5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 3                                      109000    Fuel cells
# 4          8,900 Capsule12,300 Service Module  Solar Panels
# 22                                        NaN           NaN
# 23                                        NaN  Solar panels
# 24                                 11,300 [6]           NaN
# 25                    12,055 kg(26,577 lb)[9]  Solar Panels
# 26                              1,335,000[10]  Solar Panels
# 27                                        NaN     Batteries
# 28                                        NaN    Fuel cells
# 29  5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 30                                     109000    Fuel cells
# 31         8,900 Capsule12,300 Service Module  Solar Panels
# 49                                        NaN           NaN
# 50                                        NaN  Solar panels
# 51                                 11,300 [6]           NaN
# 52                    12,055 kg(26,577 lb)[9]  Solar Panels
# 53                              1,335,000[10]  Solar Panels
#
#    Payload to/from ISS (kg)               First Space Flight  \
# 0                       NaN                      1961 (1960)
# 1                       NaN                      1965 (1964)
# 2                       NaN                      1967 (1966)
# 3             12,500/16,000                             1981
# 4                       NaN             Planned: 2021 (2014)
# 22                      NaN           Planned date not known
# 23                      NaN                    Planned: 2019
# 24                      NaN           Planned date not known
# 25              3,307/2,507             Planned: 2019 (2019)
# 26                      NaN  planned (2020) [10]planned 2023
# 27                      NaN                      1961 (1960)
# 28                      NaN                      1965 (1964)
# 29                      NaN                      1967 (1966)
# 30            12,500/16,000                             1981
# 31                      NaN             Planned: 2021 (2014)
# 49                      NaN           Planned date not known
# 50                      NaN                    Planned: 2019
# 51                      NaN           Planned date not known
# 52              3,307/2,507             Planned: 2019 (2019)
# 53                      NaN  planned (2020) [10]planned 2023
#
#    Last Space Flight        Flights        Orbit
# 0               1963  6(12)[note 1]      Orbital
# 1               1966  10(2)[note 3]      Orbital
# 2               1975  15(4)[note 3]      Orbital
# 3               2011    135[note 6]      Orbital
# 4                NaN  0 (1)[note 7]      Orbital
# 22               NaN              0      Orbital
# 23               NaN              0      Orbital
# 24               NaN              0      Orbital
# 25            Active           0(1)      Orbital
# 26               NaN              0      Orbital
# 27              1963  6(12)[note 1]  Sub-Orbital
# 28              1966  10(2)[note 3]  Sub-Orbital
# 29              1975  15(4)[note 3]  Sub-Orbital
# 30              2011    135[note 6]  Sub-Orbital
# 31               NaN  0 (1)[note 7]  Sub-Orbital
# 49               NaN              0  Sub-Orbital
# 50               NaN              0  Sub-Orbital
# 51               NaN              0  Sub-Orbital
# 52            Active           0(1)  Sub-Orbital
# 53               NaN              0  Sub-Orbital

# %%
# Reset index
test = ship_df.reset_index(drop=True)
test
# Out:
#                Spacecraft Origin                                Manufacturer  \
# 0                 Mercury    USA   McDonnell AircraftNorth American Aviation
# 1                  Gemini    USA                    McDonnell AircraftMartin
# 2                  Apollo    USA  North American AviationGrumman and Douglas
# 3   Space Shuttle orbiter    USA                       United Space Alliance
# 4                   Orion    USA                      Lockheed MartinAstrium
# 5   Biconic Space Vehicle    USA                                 Blue Origin
# 6       CST-100 Starliner    USA                                      Boeing
# 7            Dream Chaser    USA                   Sierra Nevada Corporation
# 8                Dragon 2    USA                                      SpaceX
# 9                Starship    USA                                      SpaceX
# 10                Mercury    USA   McDonnell AircraftNorth American Aviation
# 11                 Gemini    USA                    McDonnell AircraftMartin
# 12                 Apollo    USA  North American AviationGrumman and Douglas
# 13  Space Shuttle orbiter    USA                       United Space Alliance
# 14                  Orion    USA                      Lockheed MartinAstrium
# 15  Biconic Space Vehicle    USA                                 Blue Origin
# 16      CST-100 Starliner    USA                                      Boeing
# 17           Dream Chaser    USA                   Sierra Nevada Corporation
# 18               Dragon 2    USA                                      SpaceX
# 19               Starship    USA                                      SpaceX
#
#                         Range                      Launch System  \
# 0                 LEOattained           Redstone MRLVAtlas LV-3B
# 1                         LEO     Titan II GLVTitan IIIC[note 2]
# 2                       Lunar                  Saturn IBSaturn V
# 3                         LEO                      Space Shuttle
# 4                        Mars  Delta IV HeavySpace Launch System
# 5                         LEO                          New Glenn
# 6                         LEO        multiple, initially Atlas V
# 7                         LEO        multiple, initially Atlas V
# 8                         LEO                           Falcon 9
# 9   Solar System[10][note 15]                            BFR[10]
# 10                LEOattained           Redstone MRLVAtlas LV-3B
# 11                        LEO     Titan II GLVTitan IIIC[note 2]
# 12                      Lunar                  Saturn IBSaturn V
# 13                        LEO                      Space Shuttle
# 14                       Mars  Delta IV HeavySpace Launch System
# 15                        LEO                          New Glenn
# 16                        LEO        multiple, initially Atlas V
# 17                        LEO        multiple, initially Atlas V
# 18                        LEO                           Falcon 9
# 19  Solar System[10][note 15]                            BFR[10]
#
#        Crew Size Length (m)    Diameter (m)  \
# 0              1       3.34            1.89
# 1              2       5.56            3.05
# 2              3        8.5            3.91
# 3      8[note 4]      37.24     4.8[note 5]
# 4              6        3.3               5
# 5            NaN        NaN             NaN
# 6          7 [1]   5.03 [2]        4.56 [2]
# 7       7 [3][4]      9 [5]             NaN
# 8     7[note 14]     8.1[7]          3.7[8]
# 9   100[note 16]     55[10]  9[10][note 17]
# 10             1       3.34            1.89
# 11             2       5.56            3.05
# 12             3        8.5            3.91
# 13     8[note 4]      37.24     4.8[note 5]
# 14             6        3.3               5
# 15           NaN        NaN             NaN
# 16         7 [1]   5.03 [2]        4.56 [2]
# 17      7 [3][4]      9 [5]             NaN
# 18    7[note 14]     8.1[7]          3.7[8]
# 19  100[note 16]     55[10]  9[10][note 17]
#
#                              Launch mass (kg)  Power System  \
# 0                                         NaN     Batteries
# 1                                         NaN    Fuel cells
# 2   5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 3                                      109000    Fuel cells
# 4          8,900 Capsule12,300 Service Module  Solar Panels
# 5                                         NaN           NaN
# 6                                         NaN  Solar panels
# 7                                  11,300 [6]           NaN
# 8                     12,055 kg(26,577 lb)[9]  Solar Panels
# 9                               1,335,000[10]  Solar Panels
# 10                                        NaN     Batteries
# 11                                        NaN    Fuel cells
# 12  5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 13                                     109000    Fuel cells
# 14         8,900 Capsule12,300 Service Module  Solar Panels
# 15                                        NaN           NaN
# 16                                        NaN  Solar panels
# 17                                 11,300 [6]           NaN
# 18                    12,055 kg(26,577 lb)[9]  Solar Panels
# 19                              1,335,000[10]  Solar Panels
#
#    Payload to/from ISS (kg)               First Space Flight  \
# 0                       NaN                      1961 (1960)
# 1                       NaN                      1965 (1964)
# 2                       NaN                      1967 (1966)
# 3             12,500/16,000                             1981
# 4                       NaN             Planned: 2021 (2014)
# 5                       NaN           Planned date not known
# 6                       NaN                    Planned: 2019
# 7                       NaN           Planned date not known
# 8               3,307/2,507             Planned: 2019 (2019)
# 9                       NaN  planned (2020) [10]planned 2023
# 10                      NaN                      1961 (1960)
# 11                      NaN                      1965 (1964)
# 12                      NaN                      1967 (1966)
# 13            12,500/16,000                             1981
# 14                      NaN             Planned: 2021 (2014)
# 15                      NaN           Planned date not known
# 16                      NaN                    Planned: 2019
# 17                      NaN           Planned date not known
# 18              3,307/2,507             Planned: 2019 (2019)
# 19                      NaN  planned (2020) [10]planned 2023
#
#    Last Space Flight        Flights        Orbit
# 0               1963  6(12)[note 1]      Orbital
# 1               1966  10(2)[note 3]      Orbital
# 2               1975  15(4)[note 3]      Orbital
# 3               2011    135[note 6]      Orbital
# 4                NaN  0 (1)[note 7]      Orbital
# 5                NaN              0      Orbital
# 6                NaN              0      Orbital
# 7                NaN              0      Orbital
# 8             Active           0(1)      Orbital
# 9                NaN              0      Orbital
# 10              1963  6(12)[note 1]  Sub-Orbital
# 11              1966  10(2)[note 3]  Sub-Orbital
# 12              1975  15(4)[note 3]  Sub-Orbital
# 13              2011    135[note 6]  Sub-Orbital
# 14               NaN  0 (1)[note 7]  Sub-Orbital
# 15               NaN              0  Sub-Orbital
# 16               NaN              0  Sub-Orbital
# 17               NaN              0  Sub-Orbital
# 18            Active           0(1)  Sub-Orbital
# 19               NaN              0  Sub-Orbital

# %%
# Remove square bracketed notes from dataset
# for row in df3:
#     for each in row:
        
tester = "1961 (1960)"
tester.replace("[*]", "",regex=True)
tester
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-2ceafb6b1923> in <module>
#       4
#       5 tester = "1961 (1960)"
# ----> 6 tester.replace("[*]", "",regex=True)
#       7 tester
#
# TypeError: replace() takes no keyword arguments

# %%
# Remove parentheses notes/dates implying unmanned notes
test = ship_df.replace("(*)", "")
test
