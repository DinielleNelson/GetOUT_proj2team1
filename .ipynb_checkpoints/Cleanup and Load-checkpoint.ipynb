# %%
#Import dependencies
import requests
import pandas as pd
import re
import sqlite3
import uuid

# %% [markdown]
# # Astronauts Cleanup

# %%
#Read csv
file = 'astronauts.csv'
astro_df = pd.read_csv(file)
astro_df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
#           Graduate Major Military Rank         Military Branch  Space Flights  \
# 0                Geology           NaN                     NaN              2
# 1          Solar Physics           NaN                     NaN              1
# 2  Aerospace Engineering       Colonel       US Army (Retired)              2
# 3    Applied Mathematics       Colonel  US Air Force (Retired)              4
# 4           Astronautics       Colonel  US Air Force (Retired)              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
# 2                334            0               0.0
# 3                814            4              29.0
# 4                289            2               8.0
#
#                                             Missions Death Date Death Mission
# 0             STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN
# 1                              STS 51-F (Challenger)        NaN           NaN
# 2               STS-28 (Columbia), STS-43 (Atlantis)        NaN           NaN
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaN           NaN
# 4                               Gemini 12, Apollo 11        NaN           NaN

# %%
#Remove all years greater than 1991
astro_df = astro_df[astro_df['Year'] <= 1991]
astro_df.head()
# Out:
#                Name    Year  Group   Status Birth Date          Birth Place  \
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946           Warsaw, NY
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951        St. Louis, MO
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930        Montclair, NJ
# 5   Andrew M. Allen  1987.0   12.0  Retired   8/4/1955     Philadelphia, PA
# 6   Joseph P. Allen  1967.0    6.0  Retired  6/27/1937  Crawsfordsville, IN
#
#   Gender                                   Alma Mater     Undergraduate Major  \
# 2   Male    US Military Academy; Princeton University             Engineering
# 3   Male                 University of Missouri-Rolla     Applied Mathematics
# 4   Male                     US Military Academy; MIT  Mechanical Engineering
# 5   Male  Villanova University; University of Florida  Mechanical Engineering
# 6   Male           DePauw University; Yale University   Mathematics & Physics
#
#             Graduate Major       Military Rank            Military Branch  \
# 2    Aerospace Engineering             Colonel          US Army (Retired)
# 3      Applied Mathematics             Colonel     US Air Force (Retired)
# 4             Astronautics             Colonel     US Air Force (Retired)
# 5  Business Administration  Lieutenant Colonel  US Marine Corps (Retired)
# 6                  Physics                 NaN                        NaN
#
#    Space Flights  Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 2              2                334            0               0.0
# 3              4                814            4              29.0
# 4              2                289            2               8.0
# 5              3                906            0               0.0
# 6              2                313            2              12.0
#
#                                             Missions Death Date Death Mission
# 2               STS-28 (Columbia), STS-43 (Atlantis)        NaN           NaN
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaN           NaN
# 4                               Gemini 12, Apollo 11        NaN           NaN
# 5  STS-46 (Atlantis), STS-62 (Columbia), STS-75 (...        NaN           NaN
# 6              ST-5 (Columbia), STS 51-A (Discovery)        NaN           NaN

# %%
#Change floats to int
astro_df["Year"] = astro_df["Year"].astype(int)
astro_df["Group"] = astro_df["Group"].astype(int)

astro_df.head()
# Out:
#                Name  Year  Group   Status Birth Date          Birth Place  \
# 2  James C. Adamson  1984     10  Retired   3/3/1946           Warsaw, NY
# 3   Thomas D. Akers  1987     12  Retired  5/20/1951        St. Louis, MO
# 4       Buzz Aldrin  1963      3  Retired  1/20/1930        Montclair, NJ
# 5   Andrew M. Allen  1987     12  Retired   8/4/1955     Philadelphia, PA
# 6   Joseph P. Allen  1967      6  Retired  6/27/1937  Crawsfordsville, IN
#
#   Gender                                   Alma Mater     Undergraduate Major  \
# 2   Male    US Military Academy; Princeton University             Engineering
# 3   Male                 University of Missouri-Rolla     Applied Mathematics
# 4   Male                     US Military Academy; MIT  Mechanical Engineering
# 5   Male  Villanova University; University of Florida  Mechanical Engineering
# 6   Male           DePauw University; Yale University   Mathematics & Physics
#
#             Graduate Major       Military Rank            Military Branch  \
# 2    Aerospace Engineering             Colonel          US Army (Retired)
# 3      Applied Mathematics             Colonel     US Air Force (Retired)
# 4             Astronautics             Colonel     US Air Force (Retired)
# 5  Business Administration  Lieutenant Colonel  US Marine Corps (Retired)
# 6                  Physics                 NaN                        NaN
#
#    Space Flights  Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 2              2                334            0               0.0
# 3              4                814            4              29.0
# 4              2                289            2               8.0
# 5              3                906            0               0.0
# 6              2                313            2              12.0
#
#                                             Missions Death Date Death Mission
# 2               STS-28 (Columbia), STS-43 (Atlantis)        NaN           NaN
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaN           NaN
# 4                               Gemini 12, Apollo 11        NaN           NaN
# 5  STS-46 (Atlantis), STS-62 (Columbia), STS-75 (...        NaN           NaN
# 6              ST-5 (Columbia), STS 51-A (Discovery)        NaN           NaN

# %%
#Strip 'jr' from last name
def strip_jr(name):
    if "Jr." in name:
        result = name[:-4]
    else:
        result = name
    return (result)

astro_df['Name'] = astro_df['Name'].apply(strip_jr)
astro_df.head()
# Out:
#                Name  Year  Group   Status Birth Date          Birth Place  \
# 2  James C. Adamson  1984     10  Retired   3/3/1946           Warsaw, NY
# 3   Thomas D. Akers  1987     12  Retired  5/20/1951        St. Louis, MO
# 4       Buzz Aldrin  1963      3  Retired  1/20/1930        Montclair, NJ
# 5   Andrew M. Allen  1987     12  Retired   8/4/1955     Philadelphia, PA
# 6   Joseph P. Allen  1967      6  Retired  6/27/1937  Crawsfordsville, IN
#
#   Gender                                   Alma Mater     Undergraduate Major  \
# 2   Male    US Military Academy; Princeton University             Engineering
# 3   Male                 University of Missouri-Rolla     Applied Mathematics
# 4   Male                     US Military Academy; MIT  Mechanical Engineering
# 5   Male  Villanova University; University of Florida  Mechanical Engineering
# 6   Male           DePauw University; Yale University   Mathematics & Physics
#
#             Graduate Major       Military Rank            Military Branch  \
# 2    Aerospace Engineering             Colonel          US Army (Retired)
# 3      Applied Mathematics             Colonel     US Air Force (Retired)
# 4             Astronautics             Colonel     US Air Force (Retired)
# 5  Business Administration  Lieutenant Colonel  US Marine Corps (Retired)
# 6                  Physics                 NaN                        NaN
#
#    Space Flights  Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 2              2                334            0               0.0
# 3              4                814            4              29.0
# 4              2                289            2               8.0
# 5              3                906            0               0.0
# 6              2                313            2              12.0
#
#                                             Missions Death Date Death Mission
# 2               STS-28 (Columbia), STS-43 (Atlantis)        NaN           NaN
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaN           NaN
# 4                               Gemini 12, Apollo 11        NaN           NaN
# 5  STS-46 (Atlantis), STS-62 (Columbia), STS-75 (...        NaN           NaN
# 6              ST-5 (Columbia), STS 51-A (Discovery)        NaN           NaN

# %%
#Split functions
def split_first(astro_string):
    if "." in astro_string:
        if "." in astro_string.split(".")[1]:
            first_name = astro_string.split('.')[0] + "." + astro_string.split('.')[0] + "."
        else:
            first_name = astro_string.split('.')[0] + "."
    else:
        first_name = astro_string.split()[0]
    return(first_name)
        
def split_last(astro_string):
    if "." in astro_string:
        last_name = astro_string.split('.')[1]
        last_name = last_name.strip()
    else:
        last_name = astro_string.split()[1]
    return(last_name)

#Assign to new columns
astro_df['First Name'] = astro_df['Name'].apply(split_first)
astro_df['Last Name'] = astro_df['Name'].apply(split_last)


#Rename Name to Full-Name
astro_df = astro_df.rename(columns={"Name":"Full Name"})
astro_df.head()
# Out:
#           Full Name  Year  Group   Status Birth Date          Birth Place  \
# 2  James C. Adamson  1984     10  Retired   3/3/1946           Warsaw, NY
# 3   Thomas D. Akers  1987     12  Retired  5/20/1951        St. Louis, MO
# 4       Buzz Aldrin  1963      3  Retired  1/20/1930        Montclair, NJ
# 5   Andrew M. Allen  1987     12  Retired   8/4/1955     Philadelphia, PA
# 6   Joseph P. Allen  1967      6  Retired  6/27/1937  Crawsfordsville, IN
#
#   Gender                                   Alma Mater     Undergraduate Major  \
# 2   Male    US Military Academy; Princeton University             Engineering
# 3   Male                 University of Missouri-Rolla     Applied Mathematics
# 4   Male                     US Military Academy; MIT  Mechanical Engineering
# 5   Male  Villanova University; University of Florida  Mechanical Engineering
# 6   Male           DePauw University; Yale University   Mathematics & Physics
#
#             Graduate Major    ...               Military Branch Space Flights  \
# 2    Aerospace Engineering    ...             US Army (Retired)             2
# 3      Applied Mathematics    ...        US Air Force (Retired)             4
# 4             Astronautics    ...        US Air Force (Retired)             2
# 5  Business Administration    ...     US Marine Corps (Retired)             3
# 6                  Physics    ...                           NaN             2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 2                334            0               0.0
# 3                814            4              29.0
# 4                289            2               8.0
# 5                906            0               0.0
# 6                313            2              12.0
#
#                                             Missions Death Date Death Mission  \
# 2               STS-28 (Columbia), STS-43 (Atlantis)        NaN           NaN
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaN           NaN
# 4                               Gemini 12, Apollo 11        NaN           NaN
# 5  STS-46 (Atlantis), STS-62 (Columbia), STS-75 (...        NaN           NaN
# 6              ST-5 (Columbia), STS 51-A (Discovery)        NaN           NaN
#
#   First Name Last Name
# 2   James C.   Adamson
# 3  Thomas D.     Akers
# 4       Buzz    Aldrin
# 5  Andrew M.     Allen
# 6  Joseph P.     Allen
#
# [5 rows x 21 columns]

# %%
#Reorder Columns
f_column = astro_df.pop('First Name')
l_column = astro_df.pop('Last Name')
mission_column = astro_df.pop('Missions')
astro_df.insert(1, f_column.name, f_column)
astro_df.insert(2, l_column.name, l_column)
astro_df.insert(3, mission_column.name, mission_column)
astro_df.head()
# Out:
#           Full Name First Name Last Name  \
# 2  James C. Adamson   James C.   Adamson
# 3   Thomas D. Akers  Thomas D.     Akers
# 4       Buzz Aldrin       Buzz    Aldrin
# 5   Andrew M. Allen  Andrew M.     Allen
# 6   Joseph P. Allen  Joseph P.     Allen
#
#                                             Missions  Year  Group   Status  \
# 2               STS-28 (Columbia), STS-43 (Atlantis)  1984     10  Retired
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...  1987     12  Retired
# 4                               Gemini 12, Apollo 11  1963      3  Retired
# 5  STS-46 (Atlantis), STS-62 (Columbia), STS-75 (...  1987     12  Retired
# 6              ST-5 (Columbia), STS 51-A (Discovery)  1967      6  Retired
#
#   Birth Date          Birth Place Gender      ...       \
# 2   3/3/1946           Warsaw, NY   Male      ...
# 3  5/20/1951        St. Louis, MO   Male      ...
# 4  1/20/1930        Montclair, NJ   Male      ...
# 5   8/4/1955     Philadelphia, PA   Male      ...
# 6  6/27/1937  Crawsfordsville, IN   Male      ...
#
#       Undergraduate Major           Graduate Major       Military Rank  \
# 2             Engineering    Aerospace Engineering             Colonel
# 3     Applied Mathematics      Applied Mathematics             Colonel
# 4  Mechanical Engineering             Astronautics             Colonel
# 5  Mechanical Engineering  Business Administration  Lieutenant Colonel
# 6   Mathematics & Physics                  Physics                 NaN
#
#              Military Branch Space Flights  Space Flight (hr)  Space Walks  \
# 2          US Army (Retired)             2                334            0
# 3     US Air Force (Retired)             4                814            4
# 4     US Air Force (Retired)             2                289            2
# 5  US Marine Corps (Retired)             3                906            0
# 6                        NaN             2                313            2
#
#    Space Walks (hr)  Death Date Death Mission
# 2               0.0         NaN           NaN
# 3              29.0         NaN           NaN
# 4               8.0         NaN           NaN
# 5               0.0         NaN           NaN
# 6              12.0         NaN           NaN
#
# [5 rows x 21 columns]

# %%
#Remove all astronauts who didn't pursue missions
astro_df = astro_df[astro_df['Missions'].notnull()]
astro_df.head()
# Out:
#           Full Name First Name Last Name  \
# 2  James C. Adamson   James C.   Adamson
# 3   Thomas D. Akers  Thomas D.     Akers
# 4       Buzz Aldrin       Buzz    Aldrin
# 5   Andrew M. Allen  Andrew M.     Allen
# 6   Joseph P. Allen  Joseph P.     Allen
#
#                                             Missions  Year  Group   Status  \
# 2               STS-28 (Columbia), STS-43 (Atlantis)  1984     10  Retired
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...  1987     12  Retired
# 4                               Gemini 12, Apollo 11  1963      3  Retired
# 5  STS-46 (Atlantis), STS-62 (Columbia), STS-75 (...  1987     12  Retired
# 6              ST-5 (Columbia), STS 51-A (Discovery)  1967      6  Retired
#
#   Birth Date          Birth Place Gender      ...       \
# 2   3/3/1946           Warsaw, NY   Male      ...
# 3  5/20/1951        St. Louis, MO   Male      ...
# 4  1/20/1930        Montclair, NJ   Male      ...
# 5   8/4/1955     Philadelphia, PA   Male      ...
# 6  6/27/1937  Crawsfordsville, IN   Male      ...
#
#       Undergraduate Major           Graduate Major       Military Rank  \
# 2             Engineering    Aerospace Engineering             Colonel
# 3     Applied Mathematics      Applied Mathematics             Colonel
# 4  Mechanical Engineering             Astronautics             Colonel
# 5  Mechanical Engineering  Business Administration  Lieutenant Colonel
# 6   Mathematics & Physics                  Physics                 NaN
#
#              Military Branch Space Flights  Space Flight (hr)  Space Walks  \
# 2          US Army (Retired)             2                334            0
# 3     US Air Force (Retired)             4                814            4
# 4     US Air Force (Retired)             2                289            2
# 5  US Marine Corps (Retired)             3                906            0
# 6                        NaN             2                313            2
#
#    Space Walks (hr)  Death Date Death Mission
# 2               0.0         NaN           NaN
# 3              29.0         NaN           NaN
# 4               8.0         NaN           NaN
# 5               0.0         NaN           NaN
# 6              12.0         NaN           NaN
#
# [5 rows x 21 columns]

# %%
#Remove all mission related data
astro_df = astro_df.drop(["Missions"], axis=1)

#Apply sort based on Crew Member's Name
astro_df = astro_df.sort_values(by=["Full Name"])

#Reset index
astro_df = astro_df.reset_index(drop=True)

astro_df.head()
# Out:
#           Full Name First Name Last Name  Year  Group      Status  Birth Date  \
# 0  Alan B. Shepard     Alan B.   Shepard  1959      1    Deceased  11/18/1923
# 1      Alan L. Bean    Alan L.      Bean  1963      3     Retired   3/15/1932
# 2  Alfred M. Worden  Alfred M.    Worden  1966      5     Retired    2/7/1932
# 3   Andrew M. Allen  Andrew M.     Allen  1987     12     Retired    8/4/1955
# 4    Anna L. Fisher    Anna L.    Fisher  1978      8  Management   8/24/1949
#
#         Birth Place  Gender                                   Alma Mater  \
# 0    East Derry, NH    Male                             US Naval Academy
# 1       Wheeler, TX    Male                          University of Texas
# 2       Jackson, MI    Male  US Military Academy; University of Michigan
# 3  Philadelphia, PA    Male  Villanova University; University of Florida
# 4      New York, NY  Female         University of California-Los Angeles
#
#         Undergraduate Major                            Graduate Major  \
# 0            Naval Sciences                                       NaN
# 1  Aeronautical Engineering                                       NaN
# 2          Military Science  Aeronautical & Astronautical Engineering
# 3    Mechanical Engineering                   Business Administration
# 4                 Chemistry                       Chemistry; Medicine
#
#         Military Rank            Military Branch  Space Flights  \
# 0        Rear Admiral          US Navy (Retired)              2
# 1             Captain          US Navy (Retired)              2
# 2             Colonel     US Air Force (Retired)              1
# 3  Lieutenant Colonel  US Marine Corps (Retired)              3
# 4                 NaN                        NaN              1
#
#    Space Flight (hr)  Space Walks  Space Walks (hr) Death Date Death Mission
# 0                216            2               9.0  7/21/1998           NaN
# 1               1671            3              10.0        NaN           NaN
# 2                295            1               0.5        NaN           NaN
# 3                906            0               0.0        NaN           NaN
# 4                191            0               0.0        NaN           NaN

# %%
#insert first column - astro_id 
def assign_astro_id(item):
    result = "A-"+str(uuid.uuid4().fields[-1])[:5]
    return(result)
astro_df["Astro ID"] = astro_df["Full Name"].apply(assign_astro_id)

id_column = astro_df.pop('Astro ID')
astro_df.insert(0, id_column.name, id_column)

astro_df
# Out:
#     Astro ID                Full Name   First Name         Last Name  Year  \
# 0    A-15297         Alan B. Shepard       Alan B.           Shepard  1959
# 1    A-19563             Alan L. Bean      Alan L.              Bean  1963
# 2    A-16714         Alfred M. Worden    Alfred M.            Worden  1966
# 3    A-13541          Andrew M. Allen    Andrew M.             Allen  1987
# 164      8     Retired  10/27/1946              Pittsburgh, PA    Male
# 165     12     Retired   5/20/1951               St. Louis, MO    Male
# 166     13     Retired   1/22/1955               Baltimore, MD    Male
# 167      5     Retired   3/17/1936                 Chicago, IL    Male
# 168      2     Retired   9/17/1930             Weatherford, OK    Male
# 169      5     Retired    5/9/1931                Longmont, CA    Male
# 170      1    Deceased    4/3/1926                Mitchell, IN    Male
# 171      3     Retired   3/16/1932                 Creston, IA    Male
# 172      1    Deceased   3/12/1923              Hackensack, NJ    Male
# 173      3     Retired  10/17/1933                   Hong Kong    Male
# 174      6    Deceased   3/14/1939                   Miami, FL    Male
# 175      6     Retired   4/14/1929                  Faison, NC    Male
# 176      9     Retired    4/1/1946                  Dallas, TX    Male
# 177     12     Retired   1/24/1952           Quonset Point, RI    Male
# 178     13     Retired   5/14/1957                Lockport, NY    Male
# 179     10     Retired   7/26/1949               Oak Ridge, TN    Male
# 180      5     Retired   1/23/1930                  Okemah, OK    Male
# 181      3  Management   7/26/1951              Laurinburg, NC    Male
#
#          ...                                 Undergraduate Major  \
# 0        ...                                      Naval Sciences
# 1        ...                            Aeronautical Engineering
# 2        ...                                    Military Science
# 3        ...                              Mechanical Engineering
# 4        ...                                           Chemistry
# 5        ...                                             Geology
# 6        ...                                             Biology
# 7        ...                                 Ceramic Engineering
# 8        ...                               Engineering Mechanics
# 9        ...                                         Mathematics
# 10       ...                                         Engineering
# 11       ...                                                 NaN
# 12       ...                                         Engineering
# 13       ...                              Mechanical Engineering
# 14       ...                              Mechanical Engineering
# 15       ...                                             Physics
# 16       ...                                             Physics
# 17       ...                             Electronics Engineering
# 18       ...                            Aeronautical Engineering
# 19       ...                                         Engineering
# 20       ...                                  Electrical Science
# 21       ...                            Aeronautical Engineering
# 22       ...                              Engineering Management
# 23       ...                                      Naval Sciences
# 24       ...                              Electrical Engineering
# 25       ...                                 Engineering Physics
# 26       ...                               Mathematics & Physics
# 27       ...                                             Physics
# 28       ...                              Electrical Engineering
# 29       ...                                         Mathematics
# ..       ...                                                 ...
# 152      ...                                           Chemistry
# 153      ...                                         Engineering
# 154      ...                            Aeronautical Engineering
# 155      ...                               Aerospace Engineering
# 156      ...                                 Physics & Astronomy
# 157      ...                               Aerospace Engineering
# 158      ...                 Mathematics & Statistics; Chemistry
# 159      ...                            Aeronautical Engineering
# 160      ...                            Aeronautical Engineering
# 161      ...                                             Physics
# 162      ...                                   Civil Engineering
# 163      ...                                         Mathematics
# 164      ...                              Mechanical Engineering
# 165      ...                                 Applied Mathematics
# 166      ...                                                 NaN
# 167      ...                            Aeronautical Engineering
# 168      ...                                                 NaN
# 169      ...       Business Management; Aeronautical Engineering
# 170      ...                              Mechanical Engineering
# 171      ...                                             Physics
# 172      ...                                      Naval Sciences
# 173      ...                                 Nuclear Engineering
# 174      ...                              Electrical Engineering
# 175      ...                                             Physics
# 176      ...                                                 NaN
# 177      ...                               Aerospace Engineering
# 178      ...                                 Engineering Science
# 179      ...                               Aerospace Engineering
# 180      ...                                           Education
# 181      ...                       Applied Science & Engineering
#
#                                         Graduate Major       Military Rank  \
# 0                                                  NaN        Rear Admiral
# 1                                                  NaN             Captain
# 2             Aeronautical & Astronautical Engineering             Colonel
# 3                              Business Administration  Lieutenant Colonel
# 4                                  Chemistry; Medicine                 NaN
# 5                                  Geology; Geophysics                 NaN
# 6                                             Medicine                 NaN
# 7          Ceramic Engineering; Biomedical Engineering                 NaN
# 8                                Engineering Mechanics             Colonel
# 9                                   Systems Management             Colonel
# 10                                Aeronautical Systems           Commander
# 11     Electrical Engineering; Business Administration             Captain
# 12                                Aeronautical Systems             Colonel
# 13                                        Astronautics             Colonel
# 14                              Mechanical Engineering             Colonel
# 15                             Laboratory Astrophysics                 NaN
# 16                                 Solid State Physics             Colonel
# 17                             Electronics Engineering             Colonel
# 18                                                 NaN             Captain
# 19                                                 NaN  Lieutenant Colonel
# 20                                  Systems Management       Major General
# 21           Engineering Management; Strategic Studies             Colonel
# 22                                                 NaN                 NaN
# 23                                         Aeronautics   Brigadier General
# 24                                                 NaN             Colonel
# 25                                                 NaN             Captain
# 26                                                 NaN             Captain
# 27                                 Engineering Science             Captain
# 28                                            Medicine                 NaN
# 29                              Electrical Engineering             Colonel
# ..                                                 ...                 ...
# 152                                       Biochemistry                 NaN
# 153                              Aerospace Engineering             Colonel
# 154                                Business Management             Colonel
# 155                                                NaN                 NaN
# 156                           Astronomy & Astrophysics                 NaN
# 157                            Mechanical  Engineering             Colonel
# 158  Business Administration; Physiology; Literatur...                 NaN
# 159                                                NaN             Colonel
# 160                         Aeronautics & Astronautics  Lieutenant General
# 161                     Engineering Science; Astronomy                 NaN
# 162                              Public Administration             Colonel
# 163                                                NaN                 NaN
# 164     Mechanical Engineering; Electrical Engineering                 NaN
# 165                                Applied Mathematics             Colonel
# 166                                  Planetary Science                 NaN
# 167                                                NaN        Rear Admiral
# 168                                                NaN  Lieutenant General
# 169                            Business Administration                 NaN
# 170                                                NaN  Lieutenant Colonel
# 171                                            Physics             Colonel
# 172                                                NaN             Captain
# 173                                Nuclear Engineering       Major General
# 174                             Electrical Engineering                 NaN
# 175                                           Medicine                 NaN
# 176                              Engineering; Medicine                 NaN
# 177                                                NaN             Captain
# 178         Engineering Mechanics; Business Management  Lieutenant Colonel
# 179                            Mechanical  Engineering             Captain
# 180                                        Mathematics             Colonel
# 181                              Aerospace Engineering             Colonel
#
#                      Military Branch Space Flights  Space Flight (hr)  \
# 0                  US Navy (Retired)             2                216
# 1                  US Navy (Retired)             2               1671
# 2             US Air Force (Retired)             1                295
# 3          US Marine Corps (Retired)             3                906
# 4                                NaN             1                191
# 5                                NaN             1                190
# 6                                NaN             2                438
# 7                                NaN             5               1207
# 8             US Air Force (Retired)             3                533
# 9             US Air Force (Retired)             4                977
# 10          US Coast Guard (Retired)             2                311
# 11                 US Navy (Retired)             2                312
# 12         US Marine Corps (Retired)             2                383
# 13            US Air Force (Retired)             2                289
# 14            US Air Force (Retired)             2                382
# 15                               NaN             6               8970
# 16                      US Air Force             4               5533
# 17            US Air Force (Retired)             3                712
# 18                 US Navy (Retired)             4               1179
# 19                           US Army             3                581
# 20         US Marine Corps (Retired)             4                680
# 21            US Air Force (Retired)             4                950
# 22                               NaN             2                436
# 23            US Air Force (Retired)             1                265
# 24            US Air Force (Retired)             6               1383
# 25                 US Navy (Retired)             2                336
# 26                 US Navy (Retired)             4                789
# 27                 US Navy (Retired)             4               5446
# 28                               NaN             3               4044
# 29         US Marine Corps (Retired)             4                494
# ..                               ...           ...                ...
# 152                              NaN             5               5354
# 153                US Army (Retired)             1                165
# 154           US Air Force (Retired)             2                488
# 155                              NaN             3                814
# 156                              NaN             5                770
# 157           US Air Force (Retired)             4                721
# 158                              NaN             6               1281
# 159           US Air Force (Retired)             1                216
# 160                     US Air Force             5               5063
# 161                              NaN             5               1489
# 162           US Air Force (Retired)             4               1026
# 163                              NaN             4               1008
# 164                              NaN             1                167
# 165           US Air Force (Retired)             4                814
# 166                              NaN             4               1272
# 167                US Navy (Retired)             3                508
# 168           US Air Force (Retired)             4                507
# 169         US Marine Corps Reserves             4                752
# 170                     US Air Force             2                  5
# 171         US Marine Corps Reserves             1                260
# 172                US Navy (Retired)             3                295
# 173  US Air Force Reserves (Retired)             1                147
# 174                              NaN             1                122
# 175                              NaN             2                315
# 176                              NaN             1                170
# 177                US Navy (Retired)             3                672
# 178                     US Air Force             1                399
# 179                US Navy (Retired)             4               3823
# 180           US Air Force (Retired)             1               2017
# 181                US Army (Retired)             4               5398
#
#      Space Walks  Space Walks (hr)  Death Date Death Mission
# 0              2               9.0   7/21/1998           NaN
# 1              3              10.0         NaN           NaN
# 2              1               0.5         NaN           NaN
# 3              0               0.0         NaN           NaN
# 4              0               0.0         NaN           NaN
# 5              0               0.0         NaN           NaN
# 6              1               5.0         NaN           NaN
# 7              0               0.0         NaN           NaN
# 8              0               0.0         NaN           NaN
# 9              0               0.0         NaN           NaN
# 10             0               0.0         NaN           NaN
# 11             2              12.0         NaN           NaN
# 12             0               0.0         NaN           NaN
# 13             2               8.0         NaN           NaN
# 14             0               0.0         NaN           NaN
# 15             4              22.0         NaN           NaN
# 16             3              19.0         NaN           NaN
# 17             1               6.0         NaN           NaN
# 18             4              12.0    7/8/1999           NaN
# 19             0               0.0         NaN           NaN
# 20             0               0.0         NaN           NaN
# 21             0               0.0         NaN           NaN
# 22             0               0.0   10/3/1995           NaN
# 23             3              20.0         NaN           NaN
# 24             0               0.0         NaN           NaN
# 25             2              12.0         NaN           NaN
# 26             0               0.0         NaN           NaN
# 27             2              12.0         NaN           NaN
# 28             7              41.0         NaN           NaN
# 29             0               0.0         NaN           NaN
# ..           ...               ...         ...           ...
# 152            0               0.0         NaN           NaN
# 153            2              12.0         NaN           NaN
# 154            0               0.0         NaN           NaN
# 155            0               0.0         NaN           NaN
# 156            0               0.0         NaN           NaN
# 157            0               0.0         NaN           NaN
# 158            4              26.0         NaN           NaN
# 159            0               0.0  12/12/1994           NaN
# 160            1               9.0         NaN           NaN
# 161            1               8.0         NaN           NaN
# 162            0               0.0         NaN           NaN
# 163            0               0.0         NaN           NaN
# 164            0               0.0         NaN           NaN
# 165            4              29.0         NaN           NaN
# 166            3              20.0         NaN           NaN
# 167            1               1.0         NaN           NaN
# 168            0               0.0         NaN           NaN
# 169            0               0.0         NaN           NaN
# 170            0               0.0   1/27/1967      Apollo 1
# 171            0               0.0         NaN           NaN
# 172            0               0.0    5/2/2007           NaN
# 173            0               0.0         NaN           NaN
# 174            0               0.0   8/26/2012           NaN
# 175            0               0.0         NaN           NaN
# 176            2              12.0         NaN           NaN
# 177            0               0.0         NaN           NaN
# 178            0               0.0         NaN           NaN
# 179            0               0.0         NaN           NaN
# 180            2              13.0         NaN           NaN
# 181            4              24.0         NaN           NaN
#
# [182 rows x 21 columns]

# %% [markdown]
# # Mission Cleanup

# %%
#Set up url
url = 'https://www.windows2universe.org/space_missions/manned_table.html'

#Retrieve page
tables = pd.read_html(url)

#Create df
df_mission = tables[0]

df_mission.head()
# Out:
#                   0               1               2        3  \
# 0  Mission(Country)           Craft     Launch Date     Crew
# 1    Vostok-1(USSR)    Kedr (Cedar)  April 12, 1961  Gagarin
# 2    Mercury-3(USA)       Freedom 7     May 5, 1961  Shepard
# 3    Mercury-4(USA)  Liberty Bell-7   July 21, 1961  Grissom
# 4    Vostok-2(USSR)    Orel (Eagle)  August 6, 1961    Titov
#
#                                                    4
# 0                                 Mission Highlights
# 1  Cosmonaut Yuri Garagin became the first human ...
# 2  Alan Shepard became the first American in spac...
# 3  The second US sub-orbital flight, reaching an ...
# 4  Titov was the first to spend an entire day in ...

# %%
#Set up headers
df_mission.columns = df_mission.iloc[0]
df_mission = df_mission.drop(0)

#Delete "(Country)" from first column header
df_mission = df_mission.rename(columns={"Mission(Country)":"Mission"})

#Delete all rows with "(USSR)" in Mission name
df_mission = df_mission[~df_mission['Mission'].str.contains('(USSR)')]

df_mission.head()
# Out:
# C:\Users\Elizabeth Jaye\acaconda\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if __name__ == '__main__':
# 0         Mission           Craft       Launch Date       Crew  \
# 2  Mercury-3(USA)       Freedom 7       May 5, 1961    Shepard
# 3  Mercury-4(USA)  Liberty Bell-7     July 21, 1961    Grissom
# 5  Mercury-6(USA)    Friendship 7  February 20,1962      Glenn
# 6  Mercury-7(USA)        Aurora 7      May 24, 1962  Carpenter
# 9  Mercury-8(USA)         Sigma 7   October 3, 1962    Schirra
#
# 0                                 Mission Highlights
# 2  Alan Shepard became the first American in spac...
# 3  The second US sub-orbital flight, reaching an ...
# 5  The first US manned orbital flight at an orbit...
# 6  The second US manned orbital flight which orbi...
# 9  Walter Schirra orbited the Earth six times dur...

# %%
#Mission id assigning
def assign_mission_id(item):
    result = "M-"+str(uuid.uuid4().fields[-1])[:5]
    return(result)
df_mission["Mission ID"] = df_mission["Mission"].apply(assign_mission_id)

id_column = df_mission.pop('Mission ID')
df_mission.insert(0, id_column.name, id_column)
df_mission
# Out:
# 0   Mission ID                 Mission  \
# 2      M-18656          Mercury-3(USA)
# 3      M-24586          Mercury-4(USA)
# 5      M-24001          Mercury-6(USA)
# 6      M-43514          Mercury-7(USA)
# 9      M-11999          Mercury-8(USA)
# 10     M-18523          Mercury 9(USA)
# 15     M-78166     Gemini-Titan 3(USA)
# 16     M-63043     Gemini-Titan 4(USA)
# 108  Spacelab D1 was controlled by the West German ...
# 109  The crew of Mission 61-B tested space construc...
# 110  This mission had lots of problems and had to b...
# 111  All seven crew members were killed when Challe...
# 118  The Shuttle program's return to flight after t...
# 120  The third classified Department of Defense Shu...
# 121  This mission deployed the third tracking and d...
# 122  Deployed the radar mapping space probe Magella...
# 123  The fourth classified Department of Defense Sh...
# 125  Deployed the space probe Galileo, sending it o...
# 126   The fifth Department of Defense Shuttle mission.
# 127  This Shuttle mission deployed the Syncom IV-5 ...
# 129  The sixth classified Department of Defense Shu...
# 130               Deployed the Hubble Space Telescope.
# 132  Deployed the Ulysses space probe, sending it o...
# 133  The last classified Department of Defense Shut...
# 134  This Spacelab mission performed astronomical e...
# 136                Deployed the Gamma Ray Observatory.
# 137  This unclassified Department of Defense Shuttl...
#
# [71 rows x 6 columns]

# %%
#Reset Index
df_mission = df_mission.reset_index(drop=True)
df_mission.head()
# Out:
# 0 Mission ID         Mission           Craft       Launch Date       Crew  \
# 0    M-18656  Mercury-3(USA)       Freedom 7       May 5, 1961    Shepard
# 1    M-24586  Mercury-4(USA)  Liberty Bell-7     July 21, 1961    Grissom
# 2    M-24001  Mercury-6(USA)    Friendship 7  February 20,1962      Glenn
# 3    M-43514  Mercury-7(USA)        Aurora 7      May 24, 1962  Carpenter
# 4    M-11999  Mercury-8(USA)         Sigma 7   October 3, 1962    Schirra
#
# 0                                 Mission Highlights
# 0  Alan Shepard became the first American in spac...
# 1  The second US sub-orbital flight, reaching an ...
# 2  The first US manned orbital flight at an orbit...
# 3  The second US manned orbital flight which orbi...
# 4  Walter Schirra orbited the Earth six times dur...

# %%
#Delete country naming
def remove_usa(name):
    result = name.split('(')[0]
    return(result)

df_mission['Mission'] = df_mission["Mission"].apply(remove_usa)
df_mission.head()
# Out:
# 0 Mission ID    Mission           Craft       Launch Date       Crew  \
# 0    M-18656  Mercury-3       Freedom 7       May 5, 1961    Shepard
# 1    M-24586  Mercury-4  Liberty Bell-7     July 21, 1961    Grissom
# 2    M-24001  Mercury-6    Friendship 7  February 20,1962      Glenn
# 3    M-43514  Mercury-7        Aurora 7      May 24, 1962  Carpenter
# 4    M-11999  Mercury-8         Sigma 7   October 3, 1962    Schirra
#
# 0                                 Mission Highlights
# 0  Alan Shepard became the first American in spac...
# 1  The second US sub-orbital flight, reaching an ...
# 2  The first US manned orbital flight at an orbit...
# 3  The second US manned orbital flight which orbi...
# 4  Walter Schirra orbited the Earth six times dur...

# %%
#Splitting df for id and joining purposes
join_df = df_mission

mission_df=df_mission.drop(["Crew"], axis=1)
mission_df.head()
# Out:
# 0 Mission ID    Mission           Craft       Launch Date  \
# 0    M-18656  Mercury-3       Freedom 7       May 5, 1961
# 1    M-24586  Mercury-4  Liberty Bell-7     July 21, 1961
# 2    M-24001  Mercury-6    Friendship 7  February 20,1962
# 3    M-43514  Mercury-7        Aurora 7      May 24, 1962
# 4    M-11999  Mercury-8         Sigma 7   October 3, 1962
#
# 0                                 Mission Highlights
# 0  Alan Shepard became the first American in spac...
# 1  The second US sub-orbital flight, reaching an ...
# 2  The first US manned orbital flight at an orbit...
# 3  The second US manned orbital flight which orbi...
# 4  Walter Schirra orbited the Earth six times dur...

# %%
#Remove leading characters and commas from crew column (currently they are only leading, not deliminating)
join_df['Crew'] = join_df['Crew'].str.strip(',')
join_df.head()
# Out:
# 0 Mission ID    Mission           Craft       Launch Date       Crew  \
# 0    M-18656  Mercury-3       Freedom 7       May 5, 1961    Shepard
# 1    M-24586  Mercury-4  Liberty Bell-7     July 21, 1961    Grissom
# 2    M-24001  Mercury-6    Friendship 7  February 20,1962      Glenn
# 3    M-43514  Mercury-7        Aurora 7      May 24, 1962  Carpenter
# 4    M-11999  Mercury-8         Sigma 7   October 3, 1962    Schirra
#
# 0                                 Mission Highlights
# 0  Alan Shepard became the first American in spac...
# 1  The second US sub-orbital flight, reaching an ...
# 2  The first US manned orbital flight at an orbit...
# 3  The second US manned orbital flight which orbi...
# 4  Walter Schirra orbited the Earth six times dur...

# %%
#Split names for sorting
def split_it(crew_string):
    result = re.sub(r"(\w)([A-Z])", r"\1 \2", crew_string)

    if 'Mac' in result:
        result = result.replace("Mac ", "Mac")
    
    if "Mc" in result:
        result = result.replace("Mc ", "Mc")
        
    if "van den Berg" in result:
        result = "vandenBerg"
    
    if "van Hoften" in result:
        result = "vanHoften"

    return(result)

join_df['Crew'] = join_df['Crew'].apply(split_it)
join_df.head()
# Out:
# 0 Mission ID    Mission           Craft       Launch Date       Crew  \
# 0    M-18656  Mercury-3       Freedom 7       May 5, 1961    Shepard
# 1    M-24586  Mercury-4  Liberty Bell-7     July 21, 1961    Grissom
# 2    M-24001  Mercury-6    Friendship 7  February 20,1962      Glenn
# 3    M-43514  Mercury-7        Aurora 7      May 24, 1962  Carpenter
# 4    M-11999  Mercury-8         Sigma 7   October 3, 1962    Schirra
#
# 0                                 Mission Highlights
# 0  Alan Shepard became the first American in spac...
# 1  The second US sub-orbital flight, reaching an ...
# 2  The first US manned orbital flight at an orbit...
# 3  The second US manned orbital flight which orbi...
# 4  Walter Schirra orbited the Earth six times dur...

# %%
#Move Crew column to second column
my_column = join_df.pop('Crew')
join_df.insert(2, my_column.name, my_column)
join_df.head()
# Out:
# 0 Mission ID    Mission       Crew           Craft       Launch Date  \
# 0    M-18656  Mercury-3    Shepard       Freedom 7       May 5, 1961
# 1    M-24586  Mercury-4    Grissom  Liberty Bell-7     July 21, 1961
# 2    M-24001  Mercury-6      Glenn    Friendship 7  February 20,1962
# 3    M-43514  Mercury-7  Carpenter        Aurora 7      May 24, 1962
# 4    M-11999  Mercury-8    Schirra         Sigma 7   October 3, 1962
#
# 0                                 Mission Highlights
# 0  Alan Shepard became the first American in spac...
# 1  The second US sub-orbital flight, reaching an ...
# 2  The first US manned orbital flight at an orbit...
# 3  The second US manned orbital flight which orbi...
# 4  Walter Schirra orbited the Earth six times dur...

# %%
#Setting up name split per mission
df_join = pd.DataFrame(columns=join_df.columns)
df_join

#Iterate over df in order to create new df, split names appropriately so each crew member is seperate
for index, row in join_df.iterrows():
    check = row["Crew"].split(" ")
    
    for name in check:
        missionid = row["Mission ID"]
        mission = row["Mission"]
        craft = row["Craft"]
        launchdate= row["Launch Date"]
        missionhighlights = row["Mission Highlights"]
        simp_df = pd.DataFrame([[missionid, mission, name, craft, launchdate, missionhighlights]], columns=df_join.columns)
        df_join = df_join.append(simp_df)

#Apply sort based on Crew Member's Last Name
df_join = df_join.sort_values(by=["Mission"])

#Reset index
df_join = df_join.reset_index(drop=True)

df_join.head()
# Out:
# 0 Mission ID Mission        Crew       Craft       Launch Date  \
# 0    M-61838    41-B       Brand  Challenger  February 3, 1984
# 1    M-61838    41-B      Gibson  Challenger  February 3, 1984
# 2    M-61838    41-B      McNair  Challenger  February 3, 1984
# 3    M-61838    41-B     Stewart  Challenger  February 3, 1984
# 4    M-61838    41-B  McCandless  Challenger  February 3, 1984
#
# 0                                 Mission Highlights
# 0  The first untethered spacewalk in history was ...
# 1  The first untethered spacewalk in history was ...
# 2  The first untethered spacewalk in history was ...
# 3  The first untethered spacewalk in history was ...
# 4  The first untethered spacewalk in history was ...

# %%
#Final Name fix for the "van" leaders
def fix_name(crew_name):
    if "vandenBerg" in crew_name:
        name = "van den Berg"  
    elif "vanHoften" in crew_name:
        name = "van Hoften"
    else:
        name = crew_name
        
    return(name)

df_join['Crew'] = df_join['Crew'].apply(fix_name)
df_join.head()
# Out:
# 0 Mission ID Mission        Crew       Craft       Launch Date  \
# 0    M-61838    41-B       Brand  Challenger  February 3, 1984
# 1    M-61838    41-B      Gibson  Challenger  February 3, 1984
# 2    M-61838    41-B      McNair  Challenger  February 3, 1984
# 3    M-61838    41-B     Stewart  Challenger  February 3, 1984
# 4    M-61838    41-B  McCandless  Challenger  February 3, 1984
#
# 0                                 Mission Highlights
# 0  The first untethered spacewalk in history was ...
# 1  The first untethered spacewalk in history was ...
# 2  The first untethered spacewalk in history was ...
# 3  The first untethered spacewalk in history was ...
# 4  The first untethered spacewalk in history was ...

# %% [markdown]
# # Spaceship Cleanup

# %%
# Used Pandas to retrieve data from table in html rather than BeautifulSoup
# First table of Orbital crewed spaceship
df1 = (pd.read_html('https://en.wikipedia.org/wiki/Comparison_of_crewed_space_vehicles'))[1]
df1.head()
# Out:
#              0       1                        2                     3   \
# 0    Spacecraft  Origin             Manufacturer                 Range
# 1  SpaceShipOne     USA        Scaled Composites         112 kmX Prize
# 2          X-15     USA  North American Aviation        108 kmaltitude
# 3   New Shepard     USA              Blue Origin                103 km
# 4  SpaceShipTwo     USA    The Spaceship Company  110 kmKármán line+10
#
#                                4           5           6             7   \
# 0                    Launchsystem    Crewsize  Length (m)  Diameter (m)
# 1        White KnightHybrid Motor           1        8.53          8.05
# 2                 B-52Ammonia-LOX           1       15.45           6.8
# 3                New Shepard BE-3           6         NaN           NaN
# 4  White Knight TwoRocketMotorTwo  8[note 20]        18.3           8.3
#
#                  8            9                   10                   11  \
# 0  Launch mass (kg)  Powersystem  Generatedpower (W)    Firstspaceflight*
# 1              3600          NaN                 NaN                 2004
# 2             15420          NaN                 NaN                 1963
# 3               NaN          NaN                 NaN  Planned: 2019(2015)
# 4              9740          NaN                 NaN     December 13 2018
#
#                 12               13
# 0  Lastspaceflight         Flights*
# 1             2004       3[note 18]
# 2             1963       2[note 19]
# 3              NaN  0 (10)[note 19]
# 4              NaN       2[note 21]

# %%
# Gets first row as a list to use as new header
header_1 = df1.iloc[0]
header_1
# Out:
# 0             Spacecraft
# 1                 Origin
# 2           Manufacturer
# 3                  Range
# 4           Launchsystem
# 5               Crewsize
# 6             Length (m)
# 7           Diameter (m)
# 8       Launch mass (kg)
# 9            Powersystem
# 10    Generatedpower (W)
# 11     Firstspaceflight*
# 12       Lastspaceflight
# 13              Flights*
# Name: 0, dtype: object

# %%
#Rename columns for proper labels
df1.rename(columns=header_1, inplace=True)
df1.head()
# Out:
#      Spacecraft  Origin             Manufacturer                 Range  \
# 0    Spacecraft  Origin             Manufacturer                 Range
# 1  SpaceShipOne     USA        Scaled Composites         112 kmX Prize
# 2          X-15     USA  North American Aviation        108 kmaltitude
# 3   New Shepard     USA              Blue Origin                103 km
# 4  SpaceShipTwo     USA    The Spaceship Company  110 kmKármán line+10
#
#                      Launchsystem    Crewsize  Length (m)  Diameter (m)  \
# 0                    Launchsystem    Crewsize  Length (m)  Diameter (m)
# 1        White KnightHybrid Motor           1        8.53          8.05
# 2                 B-52Ammonia-LOX           1       15.45           6.8
# 3                New Shepard BE-3           6         NaN           NaN
# 4  White Knight TwoRocketMotorTwo  8[note 20]        18.3           8.3
#
#    Launch mass (kg)  Powersystem  Generatedpower (W)    Firstspaceflight*  \
# 0  Launch mass (kg)  Powersystem  Generatedpower (W)    Firstspaceflight*
# 1              3600          NaN                 NaN                 2004
# 2             15420          NaN                 NaN                 1963
# 3               NaN          NaN                 NaN  Planned: 2019(2015)
# 4              9740          NaN                 NaN     December 13 2018
#
#    Lastspaceflight         Flights*
# 0  Lastspaceflight         Flights*
# 1             2004       3[note 18]
# 2             1963       2[note 19]
# 3              NaN  0 (10)[note 19]
# 4              NaN       2[note 21]

# %%
# Add orbital type that separates table subjects
df1['Orbit'] = "Orbital"

# %%
# Second table of Sub-orbital crewed spaceship
df2 = (pd.read_html('https://en.wikipedia.org/wiki/Comparison_of_crewed_space_vehicles'))[0]
df2.head()
# Out:
#                       0       1                                           2   \
# 0             Spacecraft  Origin                                Manufacturer
# 1                Mercury     USA   McDonnell AircraftNorth American Aviation
# 2                 Gemini     USA                    McDonnell AircraftMartin
# 3                 Apollo     USA  North American AviationGrumman and Douglas
# 4  Space Shuttle orbiter     USA                       United Space Alliance
#
#             3                               4          5           6   \
# 0        Range                    Launchsystem   Crewsize  Length (m)
# 1  LEOattained        Redstone MRLVAtlas LV-3B          1        3.34
# 2          LEO  Titan II GLVTitan IIIC[note 2]          2        5.56
# 3        Lunar               Saturn IBSaturn V          3         8.5
# 4          LEO                   Space Shuttle  8[note 4]       37.24
#
#              7                                          8            9   \
# 0  Diameter (m)                           Launch mass (kg)  Powersystem
# 1          1.89                                        NaN    Batteries
# 2          3.05                                        NaN   Fuel cells
# 3          3.91  5,500 CM + 14,700 LM24,500 Service Module   Fuel cells
# 4   4.8[note 5]                                     109000   Fuel cells
#
#                         10                 11               12             13
# 0  Payloadto/from ISS (kg)  Firstspaceflight*  Lastspaceflight       Flights*
# 1                      NaN        1961 (1960)             1963  6(12)[note 1]
# 2                      NaN        1965 (1964)             1966  10(2)[note 3]
# 3                      NaN        1967 (1966)             1975  15(4)[note 3]
# 4            12,500/16,000               1981             2011    135[note 6]

# %%
#Set Column names
df2 = df2.rename(columns=df2.iloc[0]).drop(df2.index[0])
df2.head()
# Out:
#               Spacecraft Origin                                Manufacturer  \
# 1                Mercury    USA   McDonnell AircraftNorth American Aviation
# 2                 Gemini    USA                    McDonnell AircraftMartin
# 3                 Apollo    USA  North American AviationGrumman and Douglas
# 4  Space Shuttle orbiter    USA                       United Space Alliance
# 5                  Orion    USA                      Lockheed MartinAstrium
#
#          Range                       Launchsystem   Crewsize Length (m)  \
# 1  LEOattained           Redstone MRLVAtlas LV-3B          1       3.34
# 2          LEO     Titan II GLVTitan IIIC[note 2]          2       5.56
# 3        Lunar                  Saturn IBSaturn V          3        8.5
# 4          LEO                      Space Shuttle  8[note 4]      37.24
# 5         Mars  Delta IV HeavySpace Launch System          6        3.3
#
#   Diameter (m)                           Launch mass (kg)   Powersystem  \
# 1         1.89                                        NaN     Batteries
# 2         3.05                                        NaN    Fuel cells
# 3         3.91  5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 4  4.8[note 5]                                     109000    Fuel cells
# 5            5         8,900 Capsule12,300 Service Module  Solar Panels
#
#   Payloadto/from ISS (kg)     Firstspaceflight* Lastspaceflight       Flights*
# 1                     NaN           1961 (1960)            1963  6(12)[note 1]
# 2                     NaN           1965 (1964)            1966  10(2)[note 3]
# 3                     NaN           1967 (1966)            1975  15(4)[note 3]
# 4           12,500/16,000                  1981            2011    135[note 6]
# 5                     NaN  Planned: 2021 (2014)             NaN  0 (1)[note 7]

# %%
#Rename Orbit type
df2['Orbit'] = "Sub-Orbital"

# %%
# See which columns can be joined on
list(df1.columns)
# Out:
# ['Spacecraft',
#  'Origin',
#  'Manufacturer',
#  'Range',
#  'Launchsystem',
#  'Crewsize',
#  'Length (m)',
#  'Diameter (m)',
#  'Launch mass (kg)',
#  'Powersystem',
#  'Generatedpower (W)',
#  'Firstspaceflight*',
#  'Lastspaceflight',
#  'Flights*',
#  'Orbit']

# %%
# See which columns can be joined on
list(df2.columns)
# Out:
# ['Spacecraft',
#  'Origin',
#  'Manufacturer',
#  'Range',
#  'Launchsystem',
#  'Crewsize',
#  'Length (m)',
#  'Diameter (m)',
#  'Launch mass (kg)',
#  'Powersystem',
#  'Payloadto/from ISS (kg)',
#  'Firstspaceflight*',
#  'Lastspaceflight',
#  'Flights*',
#  'Orbit']

# %%
#DF Merge
df3 = df1.merge(df2,how='outer')
df3
# Out:
#                Spacecraft               Origin  \
# 0              Spacecraft               Origin
# 1            SpaceShipOne                  USA
# 2                    X-15                  USA
# 3             New Shepard                  USA
# 4            SpaceShipTwo                  USA
# 5                 Mercury                  USA
# 6                  Gemini                  USA
# 7                  Apollo                  USA
# 8   Space Shuttle orbiter                  USA
# 9                   Orion                  USA
# 10               Shenzhou                China
# 11              Gaganyaan                India
# 22                            Energia            10       36.37
# 23                           Soyuz-FG             3        7.48
# 24                           Soyuz-FG             3        7.48
# 25                           Soyuz-FG             3        7.48
# 26                    Soyuz-5Angara 5             4         NaN
# 27                          New Glenn           NaN         NaN
# 28        multiple, initially Atlas V         7 [1]    5.03 [2]
# 29        multiple, initially Atlas V      7 [3][4]       9 [5]
# 30                           Falcon 9    7[note 14]      8.1[7]
# 31                            BFR[10]  100[note 16]      55[10]
#
#       Diameter (m)                           Launch mass (kg)   Powersystem  \
# 0     Diameter (m)                           Launch mass (kg)   Powersystem
# 1             8.05                                       3600           NaN
# 2              6.8                                      15420           NaN
# 3              NaN                                        NaN           NaN
# 4              8.3                                       9740           NaN
# 5             1.89                                        NaN     Batteries
# 6             3.05                                        NaN    Fuel cells
# 7             3.91  5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 8      4.8[note 5]                                     109000    Fuel cells
# 9                5         8,900 Capsule12,300 Service Module  Solar Panels
# 10            2.80                                       7840  Solar panels
# 11               3                                       7800  Solar Panels
# 12            2.72                                        NaN     Batteries
# 13             2.4                                        NaN     Batteries
# 14            2.43                                       4725     Batteries
# 15            2.72                                        NaN  Solar panels
# 16            2.72                                        NaN  Solar panels
# 17            2.72                                        NaN  Solar panels
# 18            2.72                                        NaN  Solar panels
# 19            2.72                                        NaN  Solar panels
# 20            2.72                                        NaN  Solar panels
# 21            2.72                                        NaN  Solar panels
# 22             NaN                                        NaN    Fuel cells
# 23            2.72                                        NaN  Solar panels
# 24            2.72                                       7150  Solar panels
# 25            2.72                                        NaN  Solar panels
# 26             NaN                                        NaN  Solar panels
# 27             NaN                                        NaN           NaN
# 28        4.56 [2]                                        NaN  Solar panels
# 29             NaN                                 11,300 [6]           NaN
# 30          3.7[8]                    12,055 kg(26,577 lb)[9]  Solar Panels
# 31  9[10][note 17]                              1,335,000[10]  Solar Panels
#
#     Generatedpower (W)                Firstspaceflight*  Lastspaceflight  \
# 0   Generatedpower (W)                Firstspaceflight*  Lastspaceflight
# 1                  NaN                             2004             2004
# 2                  NaN                             1963             1963
# 3                  NaN              Planned: 2019(2015)              NaN
# 4                  NaN                 December 13 2018              NaN
# 5                  NaN                      1961 (1960)             1963
# 6                  NaN                      1965 (1964)             1966
# 7                  NaN                      1967 (1966)             1975
# 8                  NaN                             1981             2011
# 9                  NaN             Planned: 2021 (2014)              NaN
# 10                 NaN                      2003 (1999)           Active
# 11                 NaN                             2021              NaN
# 12                 NaN                             1973             1981
# 13                 NaN                      1964 (1964)             1965
# 14                 NaN                      1961 (1960)             1963
# 15                 NaN                      1967 (1966)             1970
# 16                 NaN                             1971             1971
# 17                 NaN                             1973             1973
# 18                 NaN                             1974             1975
# 19                 NaN                             1976             1976
# 20                 NaN                             1978             1986
# 21                 NaN                             1986             2002
# 22                 NaN                           (1988)           (1988)
# 23                 NaN                             2002             2012
# 24                 NaN                             2010             2016
# 25                 NaN                             2016           Active
# 26                 NaN                    Planned: 2023              NaN
# 27                 NaN           Planned date not known              NaN
# 28                 NaN                    Planned: 2019              NaN
# 29                 NaN           Planned date not known              NaN
# 30                 NaN             Planned: 2019 (2019)           Active
# 31                 NaN  planned (2020) [10]planned 2023              NaN
#
#            Flights*        Orbit Payloadto/from ISS (kg)
# 0          Flights*      Orbital                     NaN
# 1        3[note 18]      Orbital                     NaN
# 2        2[note 19]      Orbital                     NaN
# 3   0 (10)[note 19]      Orbital                     NaN
# 4        2[note 21]      Orbital                     NaN
# 5     6(12)[note 1]  Sub-Orbital                     NaN
# 6     10(2)[note 3]  Sub-Orbital                     NaN
# 7     15(4)[note 3]  Sub-Orbital                     NaN
# 8       135[note 6]  Sub-Orbital           12,500/16,000
# 9     0 (1)[note 7]  Sub-Orbital                     NaN
# 10             7(4)  Sub-Orbital                     NaN
# 11                0  Sub-Orbital                     NaN
# 12   26 (4)[note 8]  Sub-Orbital                     NaN
# 13            2 (3)  Sub-Orbital                     NaN
# 14   6 (7)[note 10]  Sub-Orbital                     NaN
# 15   8 (8)[note 11]  Sub-Orbital                     NaN
# 16       2[note 12]  Sub-Orbital                     NaN
# 17                1  Sub-Orbital                     NaN
# 18            2 (2)  Sub-Orbital                     NaN
# 19                1  Sub-Orbital                     NaN
# 20  15 (6)[note 13]  Sub-Orbital                     NaN
# 21           33 (1)  Sub-Orbital                     NaN
# 22              (1)  Sub-Orbital                     NaN
# 23               22  Sub-Orbital                     NaN
# 24               19  Sub-Orbital                     NaN
# 25                3  Sub-Orbital                     NaN
# 26                0  Sub-Orbital                     NaN
# 27                0  Sub-Orbital                     NaN
# 28                0  Sub-Orbital                     NaN
# 29                0  Sub-Orbital                     NaN
# 30             0(1)  Sub-Orbital             3,307/2,507
# 31                0  Sub-Orbital                     NaN

# %%
# Extract only US ships
ship_df = df3[df3.Origin == 'USA']
ship_df
# Out:
#                Spacecraft Origin                                Manufacturer  \
# 1            SpaceShipOne    USA                           Scaled Composites
# 2                    X-15    USA                     North American Aviation
# 3             New Shepard    USA                                 Blue Origin
# 4            SpaceShipTwo    USA                       The Spaceship Company
# 5                 Mercury    USA   McDonnell AircraftNorth American Aviation
# 6                  Gemini    USA                    McDonnell AircraftMartin
# 7                  Apollo    USA  North American AviationGrumman and Douglas
# 8   Space Shuttle orbiter    USA                       United Space Alliance
# 9                   Orion    USA                      Lockheed MartinAstrium
# 27  Biconic Space Vehicle    USA                                 Blue Origin
# 28      CST-100 Starliner    USA                                      Boeing
# 29           Dream Chaser    USA                   Sierra Nevada Corporation
# 30               Dragon 2    USA                                      SpaceX
# 31               Starship    USA                                      SpaceX
#
#                         Range                       Launchsystem  \
# 1               112 kmX Prize           White KnightHybrid Motor
# 2              108 kmaltitude                    B-52Ammonia-LOX
# 3                      103 km                   New Shepard BE-3
# 4        110 kmKármán line+10     White Knight TwoRocketMotorTwo
# 5                 LEOattained           Redstone MRLVAtlas LV-3B
# 6                         LEO     Titan II GLVTitan IIIC[note 2]
# 7                       Lunar                  Saturn IBSaturn V
# 8                         LEO                      Space Shuttle
# 9                        Mars  Delta IV HeavySpace Launch System
# 27                        LEO                          New Glenn
# 28                        LEO        multiple, initially Atlas V
# 29                        LEO        multiple, initially Atlas V
# 30                        LEO                           Falcon 9
# 31  Solar System[10][note 15]                            BFR[10]
#
#         Crewsize Length (m)    Diameter (m)  \
# 1              1       8.53            8.05
# 2              1      15.45             6.8
# 3              6        NaN             NaN
# 4     8[note 20]       18.3             8.3
# 5              1       3.34            1.89
# 6              2       5.56            3.05
# 7              3        8.5            3.91
# 8      8[note 4]      37.24     4.8[note 5]
# 9              6        3.3               5
# 27           NaN        NaN             NaN
# 28         7 [1]   5.03 [2]        4.56 [2]
# 29      7 [3][4]      9 [5]             NaN
# 30    7[note 14]     8.1[7]          3.7[8]
# 31  100[note 16]     55[10]  9[10][note 17]
#
#                              Launch mass (kg)   Powersystem  \
# 1                                        3600           NaN
# 2                                       15420           NaN
# 3                                         NaN           NaN
# 4                                        9740           NaN
# 5                                         NaN     Batteries
# 6                                         NaN    Fuel cells
# 7   5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 8                                      109000    Fuel cells
# 9          8,900 Capsule12,300 Service Module  Solar Panels
# 27                                        NaN           NaN
# 28                                        NaN  Solar panels
# 29                                 11,300 [6]           NaN
# 30                    12,055 kg(26,577 lb)[9]  Solar Panels
# 31                              1,335,000[10]  Solar Panels
#
#    Generatedpower (W)                Firstspaceflight* Lastspaceflight  \
# 1                 NaN                             2004            2004
# 2                 NaN                             1963            1963
# 3                 NaN              Planned: 2019(2015)             NaN
# 4                 NaN                 December 13 2018             NaN
# 5                 NaN                      1961 (1960)            1963
# 6                 NaN                      1965 (1964)            1966
# 7                 NaN                      1967 (1966)            1975
# 8                 NaN                             1981            2011
# 9                 NaN             Planned: 2021 (2014)             NaN
# 27                NaN           Planned date not known             NaN
# 28                NaN                    Planned: 2019             NaN
# 29                NaN           Planned date not known             NaN
# 30                NaN             Planned: 2019 (2019)          Active
# 31                NaN  planned (2020) [10]planned 2023             NaN
#
#            Flights*        Orbit Payloadto/from ISS (kg)
# 1        3[note 18]      Orbital                     NaN
# 2        2[note 19]      Orbital                     NaN
# 3   0 (10)[note 19]      Orbital                     NaN
# 4        2[note 21]      Orbital                     NaN
# 5     6(12)[note 1]  Sub-Orbital                     NaN
# 6     10(2)[note 3]  Sub-Orbital                     NaN
# 7     15(4)[note 3]  Sub-Orbital                     NaN
# 8       135[note 6]  Sub-Orbital           12,500/16,000
# 9     0 (1)[note 7]  Sub-Orbital                     NaN
# 27                0  Sub-Orbital                     NaN
# 28                0  Sub-Orbital                     NaN
# 29                0  Sub-Orbital                     NaN
# 30             0(1)  Sub-Orbital             3,307/2,507
# 31                0  Sub-Orbital                     NaN

# %%
# Rename Launchsytem, Crewsize, Powersystem, Payloadto/from ISS (kg), Firstspaceflight*, Lastspaceflight, Flights* fields
ship_df = ship_df.rename(columns={"Launchsystem":"Launch System", "Crewsize":"Crew Size", "Powersystem":"Power System", "Payloadto/from ISS (kg)":"Payload to/from ISS (kg)", "Firstspaceflight*":"First Space Flight","Lastspaceflight":"Last Space Flight", "Flights*":"Flights"})
ship_df.head()
# Out:
#      Spacecraft Origin                               Manufacturer  \
# 1  SpaceShipOne    USA                          Scaled Composites
# 2          X-15    USA                    North American Aviation
# 3   New Shepard    USA                                Blue Origin
# 4  SpaceShipTwo    USA                      The Spaceship Company
# 5       Mercury    USA  McDonnell AircraftNorth American Aviation
#
#                   Range                   Launch System   Crew Size  \
# 1         112 kmX Prize        White KnightHybrid Motor           1
# 2        108 kmaltitude                 B-52Ammonia-LOX           1
# 3                103 km                New Shepard BE-3           6
# 4  110 kmKármán line+10  White Knight TwoRocketMotorTwo  8[note 20]
# 5           LEOattained        Redstone MRLVAtlas LV-3B           1
#
#   Length (m) Diameter (m) Launch mass (kg) Power System Generatedpower (W)  \
# 1       8.53         8.05             3600          NaN                NaN
# 2      15.45          6.8            15420          NaN                NaN
# 3        NaN          NaN              NaN          NaN                NaN
# 4       18.3          8.3             9740          NaN                NaN
# 5       3.34         1.89              NaN    Batteries                NaN
#
#     First Space Flight Last Space Flight          Flights        Orbit  \
# 1                 2004              2004       3[note 18]      Orbital
# 2                 1963              1963       2[note 19]      Orbital
# 3  Planned: 2019(2015)               NaN  0 (10)[note 19]      Orbital
# 4     December 13 2018               NaN       2[note 21]      Orbital
# 5          1961 (1960)              1963    6(12)[note 1]  Sub-Orbital
#
#   Payload to/from ISS (kg)
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN

# %%
#Remove origin
ship_df = ship_df.drop(["Origin"], axis=1)

# %%
# Reset index
ship_df.reset_index(drop=True,inplace=True)
ship_df
# Out:
#                Spacecraft                                Manufacturer  \
# 0            SpaceShipOne                           Scaled Composites
# 1                    X-15                     North American Aviation
# 2             New Shepard                                 Blue Origin
# 3            SpaceShipTwo                       The Spaceship Company
# 4                 Mercury   McDonnell AircraftNorth American Aviation
# 5                  Gemini                    McDonnell AircraftMartin
# 6                  Apollo  North American AviationGrumman and Douglas
# 7   Space Shuttle orbiter                       United Space Alliance
# 8                   Orion                      Lockheed MartinAstrium
# 9   Biconic Space Vehicle                                 Blue Origin
# 10      CST-100 Starliner                                      Boeing
# 11           Dream Chaser                   Sierra Nevada Corporation
# 12               Dragon 2                                      SpaceX
# 13               Starship                                      SpaceX
#
#                         Range                      Launch System  \
# 0               112 kmX Prize           White KnightHybrid Motor
# 1              108 kmaltitude                    B-52Ammonia-LOX
# 2                      103 km                   New Shepard BE-3
# 3        110 kmKármán line+10     White Knight TwoRocketMotorTwo
# 4                 LEOattained           Redstone MRLVAtlas LV-3B
# 5                         LEO     Titan II GLVTitan IIIC[note 2]
# 6                       Lunar                  Saturn IBSaturn V
# 7                         LEO                      Space Shuttle
# 8                        Mars  Delta IV HeavySpace Launch System
# 9                         LEO                          New Glenn
# 10                        LEO        multiple, initially Atlas V
# 11                        LEO        multiple, initially Atlas V
# 12                        LEO                           Falcon 9
# 13  Solar System[10][note 15]                            BFR[10]
#
#        Crew Size Length (m)    Diameter (m)  \
# 0              1       8.53            8.05
# 1              1      15.45             6.8
# 2              6        NaN             NaN
# 3     8[note 20]       18.3             8.3
# 4              1       3.34            1.89
# 5              2       5.56            3.05
# 6              3        8.5            3.91
# 7      8[note 4]      37.24     4.8[note 5]
# 8              6        3.3               5
# 9            NaN        NaN             NaN
# 10         7 [1]   5.03 [2]        4.56 [2]
# 11      7 [3][4]      9 [5]             NaN
# 12    7[note 14]     8.1[7]          3.7[8]
# 13  100[note 16]     55[10]  9[10][note 17]
#
#                              Launch mass (kg)  Power System  \
# 0                                        3600           NaN
# 1                                       15420           NaN
# 2                                         NaN           NaN
# 3                                        9740           NaN
# 4                                         NaN     Batteries
# 5                                         NaN    Fuel cells
# 6   5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 7                                      109000    Fuel cells
# 8          8,900 Capsule12,300 Service Module  Solar Panels
# 9                                         NaN           NaN
# 10                                        NaN  Solar panels
# 11                                 11,300 [6]           NaN
# 12                    12,055 kg(26,577 lb)[9]  Solar Panels
# 13                              1,335,000[10]  Solar Panels
#
#    Generatedpower (W)               First Space Flight Last Space Flight  \
# 0                 NaN                             2004              2004
# 1                 NaN                             1963              1963
# 2                 NaN              Planned: 2019(2015)               NaN
# 3                 NaN                 December 13 2018               NaN
# 4                 NaN                      1961 (1960)              1963
# 5                 NaN                      1965 (1964)              1966
# 6                 NaN                      1967 (1966)              1975
# 7                 NaN                             1981              2011
# 8                 NaN             Planned: 2021 (2014)               NaN
# 9                 NaN           Planned date not known               NaN
# 10                NaN                    Planned: 2019               NaN
# 11                NaN           Planned date not known               NaN
# 12                NaN             Planned: 2019 (2019)            Active
# 13                NaN  planned (2020) [10]planned 2023               NaN
#
#             Flights        Orbit Payload to/from ISS (kg)
# 0        3[note 18]      Orbital                      NaN
# 1        2[note 19]      Orbital                      NaN
# 2   0 (10)[note 19]      Orbital                      NaN
# 3        2[note 21]      Orbital                      NaN
# 4     6(12)[note 1]  Sub-Orbital                      NaN
# 5     10(2)[note 3]  Sub-Orbital                      NaN
# 6     15(4)[note 3]  Sub-Orbital                      NaN
# 7       135[note 6]  Sub-Orbital            12,500/16,000
# 8     0 (1)[note 7]  Sub-Orbital                      NaN
# 9                 0  Sub-Orbital                      NaN
# 10                0  Sub-Orbital                      NaN
# 11                0  Sub-Orbital                      NaN
# 12             0(1)  Sub-Orbital              3,307/2,507
# 13                0  Sub-Orbital                      NaN

# %%
# Remove square andd round bracketed notes from dataset
ship_df.replace("\[.*\]", "",regex=True, inplace=True)
ship_df.replace("\(.*\)", "",regex=True, inplace=True)
ship_df.head()
# Out:
#      Spacecraft                               Manufacturer  \
# 0  SpaceShipOne                          Scaled Composites
# 1          X-15                    North American Aviation
# 2   New Shepard                                Blue Origin
# 3  SpaceShipTwo                      The Spaceship Company
# 4       Mercury  McDonnell AircraftNorth American Aviation
#
#                   Range                   Launch System Crew Size Length (m)  \
# 0         112 kmX Prize        White KnightHybrid Motor         1       8.53
# 1        108 kmaltitude                 B-52Ammonia-LOX         1      15.45
# 2                103 km                New Shepard BE-3         6        NaN
# 3  110 kmKármán line+10  White Knight TwoRocketMotorTwo         8       18.3
# 4           LEOattained        Redstone MRLVAtlas LV-3B         1       3.34
#
#   Diameter (m) Launch mass (kg) Power System  Generatedpower (W)  \
# 0         8.05             3600          NaN                 NaN
# 1          6.8            15420          NaN                 NaN
# 2          NaN              NaN          NaN                 NaN
# 3          8.3             9740          NaN                 NaN
# 4         1.89              NaN    Batteries                 NaN
#
#   First Space Flight Last Space Flight Flights        Orbit  \
# 0               2004              2004       3      Orbital
# 1               1963              1963       2      Orbital
# 2      Planned: 2019               NaN      0       Orbital
# 3   December 13 2018               NaN       2      Orbital
# 4              1961               1963       6  Sub-Orbital
#
#   Payload to/from ISS (kg)
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
def assign_ship_id(item):
    result = "S-"+str(uuid.uuid4().fields[-1])[:5]
    return(result)
ship_df["Spacecraft ID"] = ship_df["Spacecraft"].apply(assign_ship_id)

id_column = ship_df.pop('Spacecraft ID')
ship_df.insert(0, id_column.name, id_column)
ship_df
# Out:
#    Spacecraft ID             Spacecraft  \
# 0        S-79230           SpaceShipOne
# 1        S-23167                   X-15
# 2        S-20267            New Shepard
# 3        S-36650           SpaceShipTwo
# 4        S-15638                Mercury
# 5        S-20324                 Gemini
# 6        S-21143                 Apollo
# 7        S-55643  Space Shuttle orbiter
# 8        S-17847                  Orion
# 9        S-53004  Biconic Space Vehicle
# 10       S-16303      CST-100 Starliner
# 11       S-11781           Dream Chaser
# 12       S-14695               Dragon 2
# 13       S-18563               Starship
#
#                                   Manufacturer                 Range  \
# 0                            Scaled Composites         112 kmX Prize
# 1                      North American Aviation        108 kmaltitude
# 2                                  Blue Origin                103 km
# 3                        The Spaceship Company  110 kmKármán line+10
# 4    McDonnell AircraftNorth American Aviation           LEOattained
# 5                     McDonnell AircraftMartin                   LEO
# 6   North American AviationGrumman and Douglas                 Lunar
# 7                        United Space Alliance                   LEO
# 8                       Lockheed MartinAstrium                  Mars
# 9                                  Blue Origin                   LEO
# 10                                      Boeing                   LEO
# 11                   Sierra Nevada Corporation                   LEO
# 12                                      SpaceX                   LEO
# 13                                      SpaceX          Solar System
#
#                         Launch System Crew Size Length (m) Diameter (m)  \
# 0            White KnightHybrid Motor         1       8.53         8.05
# 1                     B-52Ammonia-LOX         1      15.45          6.8
# 2                    New Shepard BE-3         6        NaN          NaN
# 3      White Knight TwoRocketMotorTwo         8       18.3          8.3
# 4            Redstone MRLVAtlas LV-3B         1       3.34         1.89
# 5              Titan II GLVTitan IIIC         2       5.56         3.05
# 6                   Saturn IBSaturn V         3        8.5         3.91
# 7                       Space Shuttle         8      37.24          4.8
# 8   Delta IV HeavySpace Launch System         6        3.3            5
# 9                           New Glenn       NaN        NaN          NaN
# 10        multiple, initially Atlas V        7       5.03         4.56
# 11        multiple, initially Atlas V        7          9           NaN
# 12                           Falcon 9         7        8.1          3.7
# 13                                BFR       100         55            9
#
#                              Launch mass (kg)  Power System  \
# 0                                        3600           NaN
# 1                                       15420           NaN
# 2                                         NaN           NaN
# 3                                        9740           NaN
# 4                                         NaN     Batteries
# 5                                         NaN    Fuel cells
# 6   5,500 CM + 14,700 LM24,500 Service Module    Fuel cells
# 7                                      109000    Fuel cells
# 8          8,900 Capsule12,300 Service Module  Solar Panels
# 9                                         NaN           NaN
# 10                                        NaN  Solar panels
# 11                                    11,300            NaN
# 12                                  12,055 kg  Solar Panels
# 13                                  1,335,000  Solar Panels
#
#     Generatedpower (W)      First Space Flight Last Space Flight Flights  \
# 0                  NaN                    2004              2004       3
# 1                  NaN                    1963              1963       2
# 2                  NaN           Planned: 2019               NaN      0
# 3                  NaN        December 13 2018               NaN       2
# 4                  NaN                   1961               1963       6
# 5                  NaN                   1965               1966      10
# 6                  NaN                   1967               1975      15
# 7                  NaN                    1981              2011     135
# 8                  NaN          Planned: 2021                NaN      0
# 9                  NaN  Planned date not known               NaN       0
# 10                 NaN           Planned: 2019               NaN       0
# 11                 NaN  Planned date not known               NaN       0
# 12                 NaN          Planned: 2019             Active       0
# 13                 NaN   planned  planned 2023               NaN       0
#
#           Orbit Payload to/from ISS (kg)
# 0       Orbital                      NaN
# 1       Orbital                      NaN
# 2       Orbital                      NaN
# 3       Orbital                      NaN
# 4   Sub-Orbital                      NaN
# 5   Sub-Orbital                      NaN
# 6   Sub-Orbital                      NaN
# 7   Sub-Orbital            12,500/16,000
# 8   Sub-Orbital                      NaN
# 9   Sub-Orbital                      NaN
# 10  Sub-Orbital                      NaN
# 11  Sub-Orbital                      NaN
# 12  Sub-Orbital              3,307/2,507
# 13  Sub-Orbital                      NaN

# %% [markdown]
# # Joining and Merging

# %%
ship1 = ship_df[["Spacecraft ID", "Spacecraft"]]
ship1 = ship1.rename(columns={"Spacecraft":"Craft"})

ship1["Craft"] = ship1["Craft"].astype(str)
df_join["Craft"] = df_join["Craft"].astype(str)

# ship1["Craft"] = ship1["Craft"].str.encode('utf-8')

# df_join["Craft"] =  df_join["Craft"].replace('^\s+', '', regex=True, inplace=True) 
# df_join["Craft"] =  df_join["Craft"].replace('\s+$', '', regex=True, inplace=True)
# df_join["Craft"] = df_join["Craft"].str.encode('utf-8')

df_new = pd.merge(df_join, ship1, on="Craft")
df_new

if "Mercury" in ship1["Craft"]:
    print("YEP")
else:
    print("Keep crying")
    
ship1["Craft"]
# Out:
# Keep crying
# 0              SpaceShipOne
# 1                      X-15
# 2               New Shepard
# 3              SpaceShipTwo
# 4                   Mercury
# 5                    Gemini
# 6                    Apollo
# 7     Space Shuttle orbiter
# 8                     Orion
# 9     Biconic Space Vehicle
# 10        CST-100 Starliner
# 11             Dream Chaser
# 12                 Dragon 2
# 13                 Starship
# Name: Craft, dtype: object

# %%
# Out:
# 0                   Mercury
# 1                    Gemini
# 2                    Apollo
# 3     Space Shuttle orbiter
# 4                     Orion
# 5     Biconic Space Vehicle
# 6         CST-100 Starliner
# 7              Dream Chaser
# 8                  Dragon 2
# 9                  Starship
# 10                  Mercury
# 11                   Gemini
# 12                   Apollo
# 13    Space Shuttle orbiter
# 14                    Orion
# 15    Biconic Space Vehicle
# 16        CST-100 Starliner
# 17             Dream Chaser
# 18                 Dragon 2
# 19                 Starship
# Name: Craft, dtype: object

# %% [markdown]
# # Load to SQL

# %%
#Build connection
conn = sqlite3.connect('NASA.db')  
c = conn.cursor()

# %%
# #Load astro_df to table
# astro_df.to_sql('ASTRONAUTS', conn, if_exists='replace', index=False)

# #Load mission_df to table
# mission_df.to_sql('MISSIONS', conn, if_exists='replace', index=False)

# #Load ship_df to table
# ship_df.to_sql('SPACESHIPS', conn, if_exists='replace', index=False)

# #Loat join_df to table
# df_join.to_sql('MASTER', conn, if_exists='replace', index=False)
